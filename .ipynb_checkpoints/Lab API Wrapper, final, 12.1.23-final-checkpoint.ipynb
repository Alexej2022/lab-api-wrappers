# %%
# Lab | API wrappers - 
#Create your collection of songs & audio features
# Instructions
# To move forward with the project, you need to 
#create a collection of songs with their audio features
# - as large as possible!
# These are the songs that we will cluster. 
#And, later, when the user inputs a song, we will 
#find the cluster to which the song belongs and 
#recommend a song from the same cluster. 
#The more songs you have, the more accurate and 
#diverse recommendations you'll be able to give. 
#Although... you might want to make sure the 
#collected songs are "curated" in a certain way. 
#Try to find playlists of songs that are diverse, 
#but also that meet certain standards.
# The process of sending hundreds or thousands of 
#requests can take some time - it's normal if you 
#have to wait a few minutes (or, if you're ambitious, 
#even hours) to get all the data you need.
# An idea for collecting as many songs as 
#possible is to start with all the songs of a big, 
#diverse playlist and then go to every artist present 
#in the playlist and grab every song of 
#every album of that artist. 
#The amount of songs you'll be 
#collecting per playlist will grow exponentially!

# %%
secrets_file = open("secrets.txt","r")
# function open, "r" stands for reading the file
# only want to read the file
# we can access the file through the handel
# ../secrets.txt if one folder above

# %%
# These are import statements in Python, used to include packages and modules in the code.
# "import numpy as np" - This imports the 'numpy' package and gives it an alias name 'np' for easier access in the code. Numpy is a popular library for scientific computing in Python.
# "import pandas as pd" - This imports the 'pandas' package and gives it an alias name 'pd' for easier access in the code. Pandas is a library used for data analysis and manipulation in Python.
# "import spotipy" - This imports the 'spotipy' library, which provides an easy-to-use Python library for the Spotify Web API.
# "import json" - This imports the 'json' library, which provides functions for working with JSON data in Python.
# "from spotipy.oauth2 import SpotifyClientCredentials" - This imports the 'SpotifyClientCredentials' class from the 'oauth2' module within the 'spotipy' library. This class is used for authentication to access the Spotify Web API.
import numpy as np
import pandas as pd
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# contents of the file is written in a string

string = secrets_file.read()

# %%
string
# Out:
# 'clientid:dce6d8a52c174cfb9b34e5ac1976f60f\nclientsecret:3a685d939cf94ad0a891a3867314204b'

# %%
string.split('\n')
# if we split the string on the new line 
# i get 2,3 strings with the client id and an empty
# Out:
# ['clientid:dce6d8a52c174cfb9b34e5ac1976f60f',
#  'clientsecret:3a685d939cf94ad0a891a3867314204b']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'clientid': 'dce6d8a52c174cfb9b34e5ac1976f60f',
#  'clientsecret': '3a685d939cf94ad0a891a3867314204b'}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
import numpy as np
import pandas as pd
import json

# %%
playlist1 = sp.user_playlist_tracks("spotify", '4hOKQuZbraPDIfaGbM3lKI')
playlist2 = sp.user_playlist_tracks("spotify", '3SbE5Sk5MWtNc0GRTU0X6d')
playlist3 = sp.user_playlist_tracks("spotify", '2S2bAjLaE0CN2V0cTwAeEL')
playlist4 = sp.user_playlist_tracks("spotify", '2YRe7HRKNRvXdJBp9nXFza')
playlist5 = sp.user_playlist_tracks("spotify", '3eI0YMPxxoF4bOKuEqip61')
playlist6 = sp.user_playlist_tracks("spotify", '7CknELfbpyiuAZGnvCUOCb')
playlist7 = sp.user_playlist_tracks("spotify", '2pPGmv15Xs7sgvCywghrXZ')
playlist8 = sp.user_playlist_tracks("spotify", '3G1YRnuNNSfIjEtQA666rN')
playlist9 = sp.user_playlist_tracks("spotify", '4QLrLag9ZULuQ49vXc7k6n')
playlist10 = sp.user_playlist_tracks("spotify", '3OXaCg4W1wmJUXl3nH7YEw')
playlist11 = sp.user_playlist_tracks("spotify", '40y8L7CXfZYv8zgMB9asj7')
playlist12 = sp.user_playlist_tracks("spotify", '37i9dQZF1DX7Jl5KP2eZaS')
playlist13 = sp.user_playlist_tracks("spotify", '0Lf1W62a6XHBeOWzUPjoje')
playlist14 = sp.user_playlist_tracks("spotify", '4QUo8rL58cDWyySzvpButy')

# %%
# The function get_artist takes in a parameter put_the_playlist, which is assumed to be a dictionary containing a key "items" whose value is a list of dictionaries.
# The function first creates an empty list artist_1 and then iterates through each item in the list located at put_the_playlist["items"]. For each item, it appends the name of the first artist of the track, located at put_the_playlist["items"][i]['track']['artists'][0]['name'] to the artist_1 list.
# Then it creates an empty list artist_list1 and iterates through each word in the artist_1 list. For each word, it checks if it is already in the artist_list1 and if not, it appends it to the artist_list1.
# Finally, the function returns the artist_list1 list, which contains the unique names of the first artist of each track in the playlist.

# %%
def get_artist(put_the_playlist):
    
    artist_1 =[]
    for i in range (len(put_the_playlist["items"])):
         artist_1.append(put_the_playlist["items"][i]['track']['artists'][0]['name']) 

    artist_list1 = []
    for word in artist_1:
        if word not in artist_list1:
            artist_list1.append(word)  

    return artist_list1

# %%
# The function artist_list is calling the get_artist function multiple times with different parameters (playlist1, playlist2, playlist3, ..., playlist14), and concatenating the returned lists together using the + operator. The final result is a single list containing all the unique names of the first artist of each track in all the playlists.

# %%
artist_list = get_artist(playlist1) + get_artist(playlist2) + get_artist(playlist3) + get_artist(playlist4) + get_artist(playlist5) + get_artist(playlist6) + get_artist(playlist7) + get_artist(playlist8) + get_artist(playlist9) + get_artist(playlist10) + get_artist(playlist11) + get_artist(playlist12) + get_artist(playlist13) + get_artist(playlist14)

# %%
# The function creates an empty list my_artists and then iterates through each word in the artist_list. For each word, it checks if it is already in the my_artists list and if not, it appends it to the my_artists list. This operation is known as removing duplicates from a list.
# In the end, my_artists list will only contain unique artists from artist_list list, in other words it will remove all the duplicate artists from artist_list and give you a list of unique artists.

# %%
my_artists = []
for word in artist_list:
    if word not in my_artists:
        my_artists.append(word)

# %%
print(my_artists)
# Out:
# ['Luis Fonsi', 'DJ Khaled', 'Ed Sheeran', 'Kendrick Lamar', 'Future', 'The Chainsmokers', 'Zedd', 'Kygo', 'Jason Derulo', 'Miley Cyrus', 'Shawn Mendes', 'Bruno Mars', 'Clean Bandit', 'Charlie Puth', 'Drake', 'Harry Styles', 'Lil Uzi Vert', 'Maluma', 'French Montana', 'Julia Michaels', 'Martin Garrix', 'Calvin Harris', 'Post Malone', 'Cheat Codes', 'Logic', 'Imagine Dragons', 'Enrique Iglesias', 'Maggie Lindemann', 'Danny Ocean', 'Lady Gaga', 'KYLE', 'G-Eazy', 'Halsey', 'Khalid', 'Starley', 'ZAYN', 'Maroon 5', 'The Weeknd', 'Nicky Jam', 'Jax Jones', 'Niall Horan', 'Martin Jensen', 'Katy Perry', 'Wisin', 'James Arthur', 'Chris Jedi', 'Lord Huron', 'Burak Yeter', 'Pitbull', 'Kodak Black', 'Hailee Steinfeld', 'Shakira', 'Travis Scott', 'J Balvin', 'Migos', 'Sam Hunt', 'JP Cooper', 'CNCO', 'Big Sean', 'DJ Snake', 'Zion & Lennox', 'Little Mix', 'XXXTENTACION', 'blackbear', 'Daddy Yankee', 'Cashmere Cat', 'OneRepublic', 'AJR', 'Childish Gambino', 'Lorde', 'Ozuna', 'Anuel AA', 'Kiiara', 'The Rolling Stones', 'The Animals', 'Ben E. King', 'Elvis Presley', 'Big Blanco', 'Creedence Clearwater Revival', 'The Mamas & The Papas', 'Ray Charles', 'The Beatles', 'Shocking Blue', 'Etta James', 'Nina Simone', 'The Ronettes', 'David Bowie', 'Solomon Burke', 'Marvin Gaye', 'James Brown & The Famous Flames', 'Engelbert Humperdinck', 'Frankie Valli', 'The Archies', 'The Seekers', 'Neil Diamond', 'Sam Cooke', 'The Foundations', 'Dion', 'B.J. Thomas', 'Louis Armstrong', 'The Backstage Beatles', 'Led Zeppelin', 'Gerry & The Pacemakers', 'Chubby Checker', 'Johnny Cash', 'Patsy Cline', 'Procol Harum', 'The Doors', 'The Tokens', 'Jefferson Airplane', 'Buffalo Springfield', 'Simon & Garfunkel', 'Aretha Franklin', 'Van Morrison', 'The Ventures', 'Cream', 'The Trashmen', 'Elton John', 'Piano Project', 'Skeeter Davis', 'Scott McKenzie', 'Diana Ross & The Supremes', 'Frank Sinatra', 'Bob Dylan', 'Steppenwolf', 'Tom Jones', 'The Band', 'John Denver', 'Zager & Evans', 'Chuck Berry', 'Jeannie C. Riley', 'The Supremes', 'Jimi Hendrix', 'Rihanna', 'Mariah Carey', 'Michael Jackson', 'Prince', 'Whitney Houston', 'Donna Summer', 'Stevie Wonder', 'Tones And I', 'Lewis Capaldi', 'The Kid LAROI', 'Glass Animals', 'Billie Eilish', 'Juice WRLD', 'Dua Lipa', 'Queen', 'Justin Bieber', 'Hozier', 'John Legend', 'The Neighbourhood', 'Ariana Grande', 'Camila Cabello', 'Twenty One Pilots', 'Marshmello', 'Avicii', 'Passenger', 'Vance Joy', 'Macklemore & Ryan Lewis', 'Olivia Rodrigo', 'Major Lazer', 'SAINt JHN', 'Alan Walker', 'Sam Smith', 'Mark Ronson', 'Mike Posner', 'Lil Nas X', 'Ed Sheeran & Justin Bieber', 'The Killers', 'Eminem', 'Bad Bunny', '24kGoldn', 'BTS', 'Arctic Monkeys', 'Roddy Ricch', 'Oasis', 'Sia', 'J. Cole', 'Wiz Khalifa', 'Lauv', 'Lukas Graham', 'Jason Mraz', 'Nirvana', 'DaBaby', 'Pink Floyd', 'The Who', 'Eagles', 'Derek & The Dominos', 'Heart', 'ZZ Top', 'Aerosmith', 'Van Halen', 'Boston', 'Lynyrd Skynyrd', 'Dire Straits', 'AC/DC', 'The Kinks', 'Kansas', 'Jethro Tull', 'U2', 'Rush', 'Steve Miller Band', 'The Police', 'Fleetwood Mac', 'Yes', 'Santana', 'The Moody Blues', 'Don McLean', 'A$AP Rocky', 'Supertramp', 'George Harrison', 'The Cars', 'Blue Öyster Cult', 'George Thorogood & The Destroyers', 'Steely Dan', 'Emerson, Lake & Palmer', 'Joe Walsh', 'Tom Petty and the Heartbreakers', 'Ten Years After', "Pickin' On Series", 'Bob Seger', 'Free', 'The Doobie Brothers', 'Janis Joplin', 'Crosby, Stills, Nash & Young', 'Paul McCartney', 'Peter Frampton', 'The Kingsmen', 'The Beach Boys', 'The Smiths', 'my bloody valentine', 'Kate Bush', 'Radiohead', 'The Velvet Underground', 'Talking Heads', 'Television', 'King Crimson', 'Kanye West', 'New Order', 'Mobb Deep', 'Sonic Youth', 'Joy Division', 'The Cure', 'Slowdive', 'Björk', 'Cocteau Twins', 'Depeche Mode', 'Angelo Badalamenti', 'Love', 'Arcade Fire', 'Wu-Tang Clan', 'Curtis Mayfield', 'Danny Brown', 'Otis Redding', 'DJ Shadow', 'Lou Reed', 'Portishead', 'Kraftwerk', 'M.I.A.', 'Fishmans', 'Pixies', 'Ryuichi Sakamoto', ' ...

# %%
len(my_artists)
# Out:
# 723

# %%
artists = ['Luis Fonsi', 'DJ Khaled', 'Ed Sheeran', 'Kendrick Lamar', 'Future', 'The Chainsmokers', 'Zedd', 'Kygo', 'Jason Derulo', 'Miley Cyrus', 'Shawn Mendes', 'Bruno Mars', 'Clean Bandit', 'Charlie Puth', 'Drake', 'Harry Styles', 'Lil Uzi Vert', 'Maluma', 'French Montana', 'Julia Michaels', 'Martin Garrix', 'Calvin Harris', 'Post Malone', 'Cheat Codes', 'Logic', 'Imagine Dragons', 'Enrique Iglesias', 'Maggie Lindemann', 'Danny Ocean', 'Lady Gaga', 'KYLE', 'G-Eazy', 'Halsey', 'Khalid', 'Starley', 'ZAYN', 'Maroon 5', 'The Weeknd', 'Nicky Jam', 'Jax Jones', 'Niall Horan', 'Martin Jensen', 'Katy Perry', 'Wisin', 'James Arthur', 'Chris Jedi', 'Lord Huron', 'Burak Yeter', 'Pitbull', 'Kodak Black', 'Hailee Steinfeld', 'Shakira', 'Travis Scott', 'J Balvin', 'Migos', 'Sam Hunt', 'JP Cooper', 'CNCO', 'Big Sean', 'DJ Snake', 'Zion & Lennox', 'Little Mix', 'XXXTENTACION', 'blackbear', 'Daddy Yankee', 'Cashmere Cat', 'OneRepublic', 'AJR', 'Childish Gambino', 'Lorde', 'Ozuna', 'Anuel AA', 'Kiiara', 'The Animals', 'The Rolling Stones', 'Ben E. King', 'Elvis Presley', 'Creedence Clearwater Revival', 'Big Blanco', 'The Mamas & The Papas', 'The Beatles', 'Ray Charles', 'Shocking Blue', 'Etta James', 'Nina Simone', 'David Bowie', 'Solomon Burke', 'Marvin Gaye', 'The Ronettes', 'The Archies', 'James Brown & The Famous Flames', 'Engelbert Humperdinck', 'Frankie Valli', 'The Foundations', 'Neil Diamond', 'Sam Cooke', 'B.J. Thomas', 'The Seekers', 'Dion', 'Procol Harum', 'Louis Armstrong', 'Led Zeppelin', 'Chubby Checker', 'The Backstage Beatles', 'Johnny Cash', 'Gerry & The Pacemakers', 'Aretha Franklin', 'The Doors', 'Patsy Cline', 'Simon & Garfunkel', 'Van Morrison', 'Born For Bliss', 'Buffalo Springfield', 'The Tokens', 'The Ventures', 'Elton John', 'The Trashmen', 'Cream', 'Scott McKenzie', 'Skeeter Davis', 'Bob Dylan', 'Diana Ross & The Supremes', 'Steppenwolf', 'The Band', 'John Denver', 'Tom Jones', 'Frank Sinatra', 'Chuck Berry', 'The Cascades', 'Stevie Wonder', 'The Zombies', 'Zager & Evans', 'Jeannie C. Riley', 'Rihanna', 'Mariah Carey', 'Michael Jackson', 'Prince', 'Whitney Houston', 'Donna Summer', 'Tones And I', 'Lewis Capaldi', 'The Kid LAROI', 'Glass Animals', 'Billie Eilish', 'Juice WRLD', 'Dua Lipa', 'Queen', 'Justin Bieber', 'Hozier', 'John Legend', 'The Neighbourhood', 'Ariana Grande', 'Camila Cabello', 'Twenty One Pilots', 'Marshmello', 'Avicii', 'Passenger', 'Vance Joy', 'Macklemore & Ryan Lewis', 'Olivia Rodrigo', 'Major Lazer', 'SAINt JHN', 'Alan Walker', 'Sam Smith', 'Mark Ronson', 'Mike Posner', 'Lil Nas X', 'The Killers', 'Eminem', 'Bad Bunny', '24kGoldn', 'BTS', 'Arctic Monkeys', 'Roddy Ricch', 'Oasis', 'Sia', 'J. Cole', 'Wiz Khalifa', 'Lauv', 'Lukas Graham', 'Jason Mraz', 'Nirvana', 'DaBaby', 'Jimi Hendrix', 'Pink Floyd', 'The Who', 'Eagles', 'Derek & The Dominos', 'Heart', 'ZZ Top', 'Aerosmith', 'Van Halen', 'Boston', 'Lynyrd Skynyrd', 'Dire Straits', 'AC/DC', 'The Kinks', 'Kansas', 'Jethro Tull', 'U2', 'Rush', 'Steve Miller Band', 'The Police', 'Fleetwood Mac', 'Yes', 'Santana', 'The Moody Blues', 'Don McLean', 'A$AP Rocky', 'Supertramp', 'George Harrison', 'The Cars', 'Blue Öyster Cult', 'George Thorogood & The Destroyers', 'Steely Dan', 'Emerson, Lake & Palmer', 'Joe Walsh', 'Tom Petty and the Heartbreakers', 'Ten Years After', "Pickin' On Series", 'Bob Seger', 'Free', 'The Doobie Brothers', 'Janis Joplin', 'Crosby, Stills, Nash & Young', 'Paul McCartney', 'Peter Frampton', 'The Kingsmen', 'The Beach Boys', 'The Smiths', 'my bloody valentine', 'Kate Bush', 'Radiohead', 'The Velvet Underground', 'Talking Heads', 'Television', 'King Crimson', 'Kanye West', 'New Order', 'Mobb Deep', 'Sonic Youth', 'Joy Division', 'The Cure', 'Slowdive', 'Björk', 'Cocteau Twins', 'Depeche Mode', 'Angelo Badalamenti', 'Love', 'Arcade Fire', 'Wu-Tang Clan', 'Curtis Mayfield', 'Danny Brown', 'Otis Redding', 'DJ Shadow', 'Lou Reed', 'Portishead', 'Kraftwerk', 'M.I.A.', 'Fishmans', 'Pixies', 'Ryuichi Sakamoto', 'UGK', 'Outkast', 'Interpol', 'Grandmaster Flash & The Furious Five', 'The Microphones', 'Sun Kil Moon', 'The Clash', 'Spiritualized', 'Pete Rock & C.L. Smooth', 'LCD Soundsystem', 'Massive Attack', 'Echo & the Bunnymen', 'The Stone Roses', 'Mazzy Star', 'Dead Kennedys', 'The Smashing Pumpkins', 'Deftones', 'Black Sabbath', 'Geto Boys', 'The Everly Brothers', 'Domenico Modugno', 'Jerry Lee Lewis', 'Frankie Lymon & The Teenagers', 'Little Richard', 'The Coasters', 'Little Anthony & The Imperials', 'The Platters', 'The Drifters', 'The Mudlarks', 'Ritchie Valens', 'Bobby Darin', 'Dion & The Belmonts', 'A Heart Beats', 'Alma Cogan', 'The Cadillacs', 'michael holliday', 'Jimmy Lloyd', 'The Del Rios', 'The Five Satins', 'The Elegants', 'The Orioles', 'Adam Faith', 'Craig Douglas', 'The Skyliners', 'Carole King', 'Shep And The Limelites', 'Mickey & Sylvia', 'The Bobbettes', 'Carl Perkins', 'The Flamingos', 'The Crows', 'Ronnie Hawkins', 'Big Joe Turner', 'Chuck Willis', 'Connie Francis', 'Buddy Knox', 'Buddy Holly', 'The Chantels', 'The Penguins', 'Paul Anka', 'Russ Conway', 'The Isley Brothers', 'Ivory Joe Hunter', 'Billie Anthony', 'The Cleftones', 'Cliff Richard', 'Chan Romero', 'Don Lang', 'Connie Stevens', 'Bobby Day', 'LaVern Baker', 'Shirley Bassey', 'Ruth Brown', 'Jackie Wilson', 'The Marcels', 'The Chords', 'Johnny Kidd & The Pirates', 'Nat King Cole', 'Clyde McPhatter', 'Neil Sedaka', 'The Clovers', 'Max Bygraves', 'Jimmie Rodgers', 'The Monotones', 'Aaron Neville', 'Ace Cannon', 'The Ad Libs', 'Adam Wade', 'Al Hirt', 'Al Martino', 'Alan Price Set', 'Allan Sherman', 'Andy Williams', 'The Angels', 'The 5th Dimension', 'Arthur Conley', 'The Association', 'The Bar-Kays', 'The Bachelors', 'Barbara George', 'Barbara Lewis', 'Barbara Lynn', 'Barbra Streisand', 'Barbara Mason', 'Barry Mann', 'Barry McGuire', 'The Beau Brummels', 'Bert Kaempfert', 'Muzak Orchestra', 'Jerry Butler', 'Betty Everett', 'Bill Anderson', 'Bill Pursell', 'Billie Davis', 'Billy J. Kramer', 'Billie J. Kramer', 'Billy Joe & The Checkmates', 'Billy Joe Royal', 'Billy Vaughn', 'Blue Cheer', 'Blue Mink', 'The Blues Magoos', 'Bob Lind', 'Bob Moore', 'Bobby Bare', 'Bobby Freeman', 'The Bobby Fuller Four', 'James Brown', 'James Taylor', 'Freda Payne', 'Edwin Starr', 'The Guess Who', 'Three Dog Night', 'The Jackson 5', 'Deep Purple', 'Chicago', 'The Temptations', 'The Five Stairsteps', 'Grateful Dead', 'Carpenters', 'Ike & Tina Turner', 'Diana Ross', 'Gordon Lightfoot', 'Mungo Jerry', 'Yusuf / Cat Stevens', 'Lynn Anderson', 'The Spinners', 'Edison Lighthouse', 'Joni Mitchell', 'Charles Wright & The Watts 103rd Street Rhythm Band', 'Alice Cooper', 'Bread', 'Clarence Carter', 'Badfinger', 'Eric Burdon', 'The Supremes', 'The Partridge Family', 'Mountain', 'Allman Brothers Band', 'Eric Clapton', 'The Dawn', 'Gladys Knight & The Pips', 'Neil Young', 'Crosby, Stills & Nash', 'King Floyd', 'Sugarloaf', 'Tyrone Davis', 'Dave Edmunds', 'Tommy James', 'Loretta Lynn', 'Christie', 'Grand Funk Railroad', 'The Moments', 'James Gang', 'Bee Gees', 'The Ides Of March', 'Nitty Gritty Dirt Band', 'Ray Price', 'Blues Image', 'Blondie', 'Lipps Inc.', 'Billy Joel', 'Bette Midler', 'Rupert Holmes', 'Gary Numan', 'Smokey Robinson', 'Air Supply', 'Styx', 'The Manhattans', 'Commodores', 'Dr. Hook', 'Robbie Dupree', 'Ambrosia', 'Kenny Loggins', 'Jermaine Jackson', 'Christopher Cross', 'Dan Fogelberg', 'Kenny Rogers', 'The S.O.S Band', 'Kim Carnes', 'M', 'Shalamar', 'The Brothers Johnson', 'Rocky Burnette', 'Herb Alpert', 'Little River Band', 'JD Souther', 'Andy Gibb', 'Steve Forbert', 'Anne Murray', 'Isaac Hayes', 'The Alan Peters Orchestra And Chorus', 'Linda Ronstadt', 'Benny Mardones', 'Pure Prairie League', 'Genesis', 'Mickey Gilley', 'Pat Benatar', 'Dionne Warwick', 'Eddie Rabbitt', 'George Benson', 'Boz Scaggs', 'Barry Manilow', 'Rick Springfield', 'Dolly Parton', 'REO Speedwagon', 'Joey Scarbury', 'Sheena Easton', 'Grover Washington, Jr.', 'The Pointer Sisters', 'A Taste Of Honey', 'ABBA', 'Stars On 45', 'Juice Newton', 'Ronnie Milsap', 'The Manhattan Transfer', 'Foreigner', 'Rod Stewart', 'Marty Balin', 'Champaign', 'The Alan Parsons Project', 'Rilo Kiley', 'Jimmy Eat World', 'Brandi Carlile', 'The Gaslight Anthem', 'Metric', 'Silversun Pickups', 'Amy Winehouse', 'M83', 'The Roots', 'The National', 'Feist', 'The Shins', 'La Roux', 'Superdrag', 'Aaliyah', 'Ween', 'The Raveonettes', 'The Hives', 'blink-182', 'Goldfrapp', 'Fountains Of Wayne', 'Queens of the Stone Age', 'Kings of Leon', 'The Hold Steady', 'The Walkmen', 'The Avalanches', 'Travis', 'Boy Kill Boy', 'Yeah Yeah Yeahs', 'Band of Horses', 'Fleet Foxes', 'Mogwai', 'The White Stripes', 'St. Vincent', 'Bruce Springsteen', 'Alter Bridge', 'PJ Harvey', 'Eddie Vedder', 'The Cribs', 'Duran Duran', 'Pinback', 'The Rosebuds', 'Sad Brad Smith', 'The Republic Tigers', 'The Features', 'The Big Pink', 'Empire of the Sun', 'Great Northern', 'White Denim', 'The Oohlas', 'Tom Vek', 'The Rapture', 'Ivy', 'The Virgins', 'Miike Snow', 'Fuzzbubble', 'Bombay Bicycle Club', 'Chromeo', 'The Bravery', 'Foo Fighters', 'JEFF The Brotherhood', 'Red Hot Chili Peppers', 'Sea Power', 'Spoon', 'Paper Route', 'Phoenix', 'The Cinematics', 'Unwritten Law', 'The Sounds', 'Blonde Redhead', 'Powfu', 'Trevor Daniel', 'KAROL G', 'Arizona Zervas', 'Lil Mosey', 'Doja Cat', 'Jawsh 685', 'Topic', 'Cardi B', 'Surfaces', 'BENEE', 'Surf Mesa', 'Regard', 'Black Eyed Peas', 'THE SCOTTS', 'JP Saxe', 'Wolf Alice', 'Pure Bathing Culture', 'St. Lucia', 'Karen O', 'Now, Now', 'The Midnight', 'Angel Olsen', 'HAIM', 'DIIV', 'Middle Kids', 'Sharon Van Etten', 'White Lies', 'CHVRCHES', 'The Strokes', 'Leon Bridges', 'Caroline Rose', 'Chromatics', 'The Pains Of Being Pure At Heart', 'Holy Ghost!', 'Alvvays', 'Washed Out', 'Foals', 'Chairlift', 'Cate Le Bon', 'Neon Indian', 'Paramore', 'Girls', 'Best Coast', 'Lykke Li', 'Kitten', 'Cloud Nothings', 'Charly Bliss', 'The Chain Gang Of 1974', 'Martha', 'Big Talk', 'Francis and the Lights', 'Big Smoke', 'The Maccabees', 'Porter Robinson', 'Courtney Barnett', 'Jenny Lewis', 'Bob Mould', 'Broken Bells', 'Alabama Shakes', 'Sturgill Simpson', 'Kurt Vile', 'Sunflower Bean', 'SAULT', 'The Preatures', 'Antarctigo Vespucci', 'The Presets', "DMA'S", 'Frightened Rabbit', 'Weezer', 'Nation of Language', 'HAERTS', 'Japandroids', 'Todd Terje', 'Night Moves', 'Sundara Karma', 'Phosphorescent', 'The Beths', 'Thundercat', 'Charli XCX', 'HalfNoise', 'Lana Del Rey', 'Neon Trees', 'Lucy Dacus', 'Sylvan Esso', 'MisterWives', 'Twin Shadow', 'Cliff Richard & The Shadows', 'Jacques Brel', 'Margriet Eshuijs', 'Ramses Shaffy', 'Jan Smit', 'Skik', 'Scorpions', 'The Shoes', 'Sonny & Cher', 'Bill Withers', 'Glen Campbell', 'Cuby & The Blizzards', 'Vera Lynn', 'Michel Fugain & Le Big Bazar', 'George Michael', 'Herman Brood & His Wild Romance', 'Simply Red', 'Nicole', 'BLØF', 'Gerard Cox', 'Marmalade', 'Mort Shuman', 'Crispian St. Peters', 'Anita Meyer', 'Herman van Veen', 'Wim Sonneveld', 'The Shadows', 'Rob De Nijs', 'Mud', 'Zen', 'Lionel Richie', 'Pat Boone', 'Rod McKuen', 'Conny Vandenbos', 'BZN', 'Udo Jürgens', 'Doe Maar', 'Paul Simon', 'Normaal', 'Boudewijn de Groot', 'Marianne Faithfull', 'Het Goede Doel', 'Roberta Flack', 'Anneke Gronloh', 'Focus', 'Phil Collins', 'Mighty Sparrow & Byron Lee', 'Europe', 'Del Shannon', 'Johnny Hallyday', 'Carly Simon', 'Salvatore Adamo', 'Ten Sharp', 'Eros Ramazzotti', 'Andre Hazes', 'Sting', 'Roy Orbison', 'Marillion', 'Rowwen Hèze', 'Willeke Alberti', 'Racoon']

# %%
len(artists)
# Out:
# 721

# %%
from random import randint
from time import sleep

# %%
# # The function creates an empty list my_3_tracks and iterates through each artist in the artists list.
# For each artist, it calls the sp.search() function, 
# which is likely the Spotify Web API's search function, 
# with the parameters q=artist and limit=10. 
# This is likely searching Spotify's database for the top 10 songs by the current artist. 
# The returned result from the search function is then appended to the my_3_tracks list.
# # It's also worth noting that there is an commented line sleep(randint(1,2)) 
# which indicates that it waits for a random time between 1 and 2 
# seconds before making the next API call. This is done to avoid 
# overloading the API with too many requests in a short amount of time.

# %%
my_3_tracks = []

for artist in artists:
    my_3_tracks.append(sp.search(q=artist, limit=10))
#     sleep(randint(1,2))

# %%
# my_3_tracks = []

# for artist in artists:   
#     my_3_tracks.append(sp.search(q=artist, limit=10))

# %%
# The function creates three empty lists songs_30, songs_30_uri, songs_30_url.
# Then, it iterates through a range of 721 and for each iteration, 
#it again iterates through a range of 10.
# For each of these nested iterations, it uses the values of i and j to 
#access elements in the my_3_tracks list. It then appends the name, URI and 
#external url of the track to the 
#songs_30, songs_30_uri, songs_30_url lists respectively.

# In summary, the function is iterating over the my_3_tracks list and 
#extracting the track name, URI and external URL of each track, and 
#appending it to the corresponding list. The resulting songs_30 list 
#contains the name of each track, songs_30_uri contains the URI of 
#each track, and songs_30_url contains the external URL of each track. 
#This way, you'll have three lists with the information of each track, 
#that information can be used for further processing or displaying.

# %%
# range differs according to artist count
songs_30 = []
songs_30_uri = []
songs_30_url = []
for i in range(721):
    for j in range(10):
        songs_30.append(my_3_tracks[i]['tracks']['items'][j]['name'])
        songs_30_uri.append(my_3_tracks[i]['tracks']['items'][j]['uri'])
        songs_30_url.append(my_3_tracks[i]['tracks']['items'][j]['external_urls']['spotify'])

# %%
# The function creates an empty list songs_30_artists and then iterates through the artists list. 
#For each artist in the list, it creates a new variable j with the value of 10 and enters a while loop. 
#The loop will execute as long as the value of j is not equal to 0.
# In each iteration of the loop, the current artist from the artists list is 
#appended to the songs_30_artists list, and the value of j is decremented by 1.
# So, the function is iterating through the artists list and appending 
#each artist to the songs_30_artists list 10 times. 
#This means that if there are n artists in the artists list, 
#then the songs_30_artists list will have n*10 elements, 
#where each artist is repeated 10 times.

# %%
songs_30_artists = []
for i in range(len(artists)):
    j = 10
    while j != 0:
        songs_30_artists.append(artists[i])
        j-=1

# %%
# range len artist * 10
songs_30_features = []
for i in range(5940):
    songs_30_features.append(sp.audio_features(songs_30_uri[i]))

# %%
# The function flatten(input_list) takes one argument, an input_list, and returns a new list.
# It uses a list comprehension to iterate through input_list, 
#where for each sublist within input_list, it iterates through each item in the sublist, 
#and appends it to a new list which is returned by the function.
# In other words, the function takes a nested list 
#(a list that has one or more lists within it) and "flattens" it, 
#meaning it converts it into a single-level list by merging all the 
#sublists and their elements into a single list, 
#which is returned by the function.
# For example, if the input_list is [[1, 2, 3], [4, 5], [6, 7, 8, 9]], 
#the function will return [1, 2, 3, 4, 5, 6, 7, 8, 9].

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
songs_30_features = flatten(songs_30_features)

# %%
songs_30_features
# Out:
# [{'danceability': 0.655,
#   'energy': 0.797,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.153,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.067,
#   'valence': 0.839,
#   'tempo': 177.928,
#   'type': 'audio_features',
#   'id': '6habFhsOp2NvshLv26DqMb',
#   'uri': 'spotify:track:6habFhsOp2NvshLv26DqMb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6habFhsOp2NvshLv26DqMb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6habFhsOp2NvshLv26DqMb',
#   'duration_ms': 229360,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.488,
#   'key': 4,
#   'loudness': -6.287,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.775,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.153,
#   'tempo': 118.21,
#   'type': 'audio_features',
#   'id': '0LwCtv2JW5yTl5qd91e4tL',
#   'uri': 'spotify:track:0LwCtv2JW5yTl5qd91e4tL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0LwCtv2JW5yTl5qd91e4tL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LwCtv2JW5yTl5qd91e4tL',
#   'duration_ms': 247800,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.897,
#   'key': 0,
#   'loudness': -3.652,
#   'mode': 1,
#   'speechiness': 0.0389,
#   'acousticness': 0.0391,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'valence': 0.649,
#   'tempo': 96.006,
#   'type': 'audio_features',
#   'id': '0mlAOSILGRys2IbvyOT5VJ',
#   'uri': 'spotify:track:0mlAOSILGRys2IbvyOT5VJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mlAOSILGRys2IbvyOT5VJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mlAOSILGRys2IbvyOT5VJ',
#   'duration_ms': 173800,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.816,
#   'key': 2,
#   'loudness': -4.353,
#   'mode': 1,
#   'speechiness': 0.167,
#   'acousticness': 0.228,
#   'instrumentalness': 0,
#   'liveness': 0.0967,
#   'valence': 0.816,
#   'tempo': 178.085,
#   'type': 'audio_features',
#   'id': '6rPO02ozF3bM7NnOV4h6s2',
#   'uri': 'spotify:track:6rPO02ozF3bM7NnOV4h6s2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6rPO02ozF3bM7NnOV4h6s2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rPO02ozF3bM7NnOV4h6s2',
#   'duration_ms': 228827,
#   'time_signature': 4},
#  {'danceability': 0.768,
#   'energy': 0.529,
#   'key': 1,
#   'loudness': -6.758,
#   'mode': 1,
#   'speechiness': 0.0405,
#   'acousticness': 0.79,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.517,
#   'tempo': 119.953,
#   'type': 'audio_features',
#   'id': '609SDGj0txmlAXRrpwee9Y',
#   'uri': 'spotify:track:609SDGj0txmlAXRrpwee9Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/609SDGj0txmlAXRrpwee9Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/609SDGj0txmlAXRrpwee9Y',
#   'duration_ms': 221947,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.798,
#   'key': 2,
#   'loudness': -4.346,
#   'mode': 1,
#   'speechiness': 0.178,
#   'acousticness': 0.226,
#   'instrumentalness': 0,
#   'liveness': 0.0711,
#   'valence': 0.857,
#   'tempo': 177.899,
#   'type': 'audio_features',
#   'id': '1vnnXMrBeEWiRg3YCMCjQq',
#   'uri': 'spotify:track:1vnnXMrBeEWiRg3YCMCjQq',
#   'track_href': 'https://api.spotify.com/v1/tracks/1vnnXMrBeEWiRg3YCMCjQq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1vnnXMrBeEWiRg3YCMCjQq',
#   'duration_ms': 230413,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.766,
#   'key': 10,
#   'loudness': -5.467,
#   'mode': 1,
#   'speechiness': 0.069,
#   'acousticness': 0.0348,
#   'instrumentalness': 0,
#   'liveness': 0.0787,
#   'valence': 0.806,
#   'tempo': 117.948,
#   'type': 'audio_features',
#   'id': '37qPzPVOfxSDI7QOF2oZFB',
#   'uri': 'spotify:track:37qPzPVOfxSDI7QOF2oZFB',
#   'track_href': 'https://api.spotify.com/v1/tracks/37qPzPVOfxSDI7QOF2oZFB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37qPzPVOfxSDI7QOF2oZFB',
#   'duration_ms': 173013,
#   'time_signature': 4},
#  {'danceability': 0.521,
#   'energy': 0.512,
#   'key': 4,
#   'loudness': -8.391,
#   'mode': 0,
#   'speechiness': 0.0394,
#   'acousticness': 0.21,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.499,
#   'tempo': 155.896,
#   'type': 'audio_features',
#   'id': '5ToI5oXnUmX5Nsmg8enL1N',
#   'uri': 'spotify:track:5ToI5oXnUmX5Nsmg8enL1N',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ToI5oXnUmX5Nsmg8enL1N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ToI5oXnUmX5Nsmg8enL1N',
#   'duration_ms': 239827,
#   'time_signature': 4},
#  {'danceability': 0.786,
#   'energy': 0.715,
#   'key': 0,
#   'loudness': -5.557,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.0913,
#   'instrumentalness': 0,
#   'liveness': 0.0701,
#   'valence': 0.92,
#   'tempo': 139.966,
#   'type': 'audio_features',
#   'id': '1h4nRJO8PFNr5FCvzBh9WU',
#   'uri': 'spotify:track:1h4nRJO8PFNr5FCvzBh9WU',
#   'track_href': 'https://api.spotify.com/v1/tracks/1h4nRJO8PFNr5FCvzBh9WU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1h4nRJO8PFNr5FCvzBh9WU',
#   'duration_ms': 169707,
#   'time_signature': 4},
#  {'danceability': 0.866,
#   'energy': 0.86,
#   'key': 1,
#   'loudness': -3.087,
#   'mode': 0,
#   'speechiness': 0.0584,
#   'acousticness': 0.138,
#   'instrumentalness': 0,
#   'liveness': 0.402,
#   'valence': 0.924,
#   'tempo': 109.973,
#   'type': 'audio_features',
#   'id': '0ej1m6qQ6XnjfFa7Zb2lz0',
#   'uri': 'spotify:track:0ej1m6qQ6XnjfFa7Zb2lz0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ej1m6qQ6XnjfFa7Zb2lz0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ej1m6qQ6XnjfFa7Zb2lz0',
#   'duration_ms': 200347,
#   'time_signature': 4},
#  {'danceability': 0.477,
#   'energy': 0.727,
#   'key': 2,
#   'loudness': -4.053,
#   'mode': 1,
#   'speechiness': 0.286,
#   'acousticness': 0.000866,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.227,
#   'tempo': 150.062,
#   'type': 'audio_features',
#   'id': '1EJIcDYXwSqipW5dFe4uJz',
#   'uri': 'spotify:track:1EJIcDYXwSqipW5dFe4uJz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1EJIcDYXwSqipW5dFe4uJz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1EJIcDYXwSqipW5dFe4uJz',
#   'duration_ms': 236524,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.667,
#   'key': 7,
#   'loudness': -4.267,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.0533,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.817,
#   'tempo': 80.984,
#   'type': 'audio_features',
#   'id': '1jYiIOC5d6soxkJP81fxq2',
#   'uri': 'spotify:track:1jYiIOC5d6soxkJP81fxq2',
#   'track_href': 'https://api.spotify.com/v1/tracks/1jYiIOC5d6soxkJP81fxq2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jYiIOC5d6soxkJP81fxq2',
#   'duration_ms': 288877,
#   'time_signature': 4},
#  {'danceability': 0.718,
#   'energy': 0.461,
#   'key': 4,
#   'loudness': -7.676,
#   'mode': 0,
#   'speechiness': 0.0797,
#   'acousticness': 0.068,
#   'instrumentalness': 0,
#   'liveness': 0.283,
#   'valence': 0.181,
#   'tempo': 129.953,
#   'type': 'audio_features',
#   'id': '0g2Bbgy7P41pFjMWJuzsf4',
#   'uri': 'spotify:track:0g2Bbgy7P41pFjMWJuzsf4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0g2Bbgy7P41pFjMWJuzsf4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0g2Bbgy7P41pFjMWJuzsf4',
#   'duration_ms': 178176,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.781,
#   'key': 10,
#   'loudness': -3.616,
#   'mode': 1,
#   'speechiness': 0.185,
#   'acousticness': 0.0139,
#   'instrumentalness': 0,
#   'liveness': 0.161,
#   'valence': 0.277,
#   'tempo': 150.097,
#   'type': 'audio_features',
#   'id': '12PNcnMsjsZ3eHm62t8hiy',
#   'uri': 'spotify:track:12PNcnMsjsZ3eHm62t8hiy',
#   'track_href': 'https://api.spotify.com/v1/tracks/12PNcnMsjsZ3eHm62t8hiy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12PNcnMsjsZ3eHm62t8hiy',
#   'duration_ms': 232507,
#   'time_signature': 4},
#  {'danceability': 0.398,
#   'energy': 0.626,
#   'key': 1,
#   'loudness': -4.164,
#   'mode': 0,
#   'speechiness': 0.0367,
#   'acousticness': 0.195,
#   'instrumentalness': 2.55e-05,
#   'liveness': 0.16,
#   'valence': 0.0404,
#   'tempo': 106.733,
#   'type': 'audio_features',
#   'id': '510mvRgE4jLSsJcBh2pH0j',
#   'uri': 'spotify:track:510mvRgE4jLSsJcBh2pH0j',
#   'track_href': 'https://api.spotify.com/v1/tracks/510mvRgE4jLSsJcBh2pH0j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/510mvRgE4jLSsJcBh2pH0j',
#   'duration_ms': 47354,
#   'time_signature': 3},
#  {'danceability': 0.765,
#   'energy': 0.872,
#   'key': 10,
#   'loudness': -4.241,
#   'mode': 0,
#   'speechiness': 0.0775,
#   'acousticness': 0.143,
#   'instrumentalness': 0,
#   'liveness': 0.495,
#   'valence': 0.578,
#   'tempo': 112.607,
#   'type': 'audio_features',
#   'id': '6YdzlsQcyXoWjAykR0rjj3',
#   'uri': 'spotify:track:6YdzlsQcyXoWjAykR0rjj3',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YdzlsQcyXoWjAykR0rjj3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YdzlsQcyXoWjAykR0rjj3',
#   'duration_ms': 263280,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.716,
#   'key': 1,
#   'loudness': -4.012,
#   'mode': 0,
#   'speechiness': 0.166,
#   'acousticness': 0.0196,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.681,
#   'tempo': 147.959,
#   'type': 'audio_features',
#   'id': '47IySiC5o08gz0z5VDiH93',
#   'uri': 'spotify:track:47IySiC5o08gz0z5VDiH93',
#   'track_href': 'https://api.spotify.com/v1/tracks/47IySiC5o08gz0z5VDiH93',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47IySiC5o08gz0z5VDiH93',
#   'duration_ms': 207650,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.495,
#   'key': 4,
#   'loudness': -7.174,
#   'mode': 0,
#   'speechiness': 0.0821,
#   'acousticness': 0.0668,
#   'instrumentalness': 0,
#   'liveness': 0.319,
#   'valence': 0.152,
#   'tempo': 129.974,
#   'type': 'audio_features',
#   'id': '7Ddk8FhoYKdsVoX9AOCPMm',
#   'uri': 'spotify:track:7Ddk8FhoYKdsVoX9AOCPMm',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Ddk8FhoYKdsVoX9AOCPMm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Ddk8FhoYKdsVoX9AOCPMm',
#   'duration_ms': 178176,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.565,
#   'key': 5,
#   'loudness': -4.711,
#   'mode': 0,
#   'speechiness': 0.235,
#   'acousticness': 0.0558,
#   'instrumentalness': 0,
#   'liveness': 0.141,
#   'valence': 0.474,
#   'tempo': 163.085,
#   'type': 'audio_features',
#   'id': '1sbEeUY8KsdvgiQi26JBFz',
#   'uri': 'spotify:track:1sbEeUY8KsdvgiQi26JBFz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sbEeUY8KsdvgiQi26JBFz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sbEeUY8KsdvgiQi26JBFz',
#   'duration_ms': 200221,
#   'time_signature': 4},
#  {'danceability': 0.413,
#   'energy': 0.807,
#   'key': 11,
#   'loudness': -3.499,
#   'mode': 0,
#   'speechiness': 0.318,
#   'acousticness': 0.0536,
#   'instrumentalness': 0,
#   'liveness': 0.631,
#   'valence': 0.438,
#   'tempo': 149.33,
#   'type': 'audio_features',
#   'id': '608a1wIsSd5KzMEqm1O7w3',
#   'uri': 'spotify:track:608a1wIsSd5KzMEqm1O7w3',
#   'track_href': 'https://api.spotify.com/v1/tracks/608a1wIsSd5KzMEqm1O7w3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/608a1wIsSd5KzMEqm1O7w3',
#   'duration_ms': 296147,
#   'time_signature': 4},
#  {'danceability': 0.788,
#   'energy': 0.859,
#   'key': 2,
#   'loudness': -2.724,
#   'mode': 1,
#   'speechiness': 0.0856,
#   'acousticness': 0.281,
#   'instrumentalness': 0,
#   'liveness': 0.0424,
#   'valence': 0.822,
#   'tempo': 141.02,
#   'type': 'audio_features',
#   'id': '50nfwKoDiSYg8zOCREWAm5',
#   'uri': 'spotify:track:50nfwKoDiSYg8zOCREWAm5',
#   'track_href': 'https://api.spotify.com/v1/tracks/50nfwKoDiSYg8zOCREWAm5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50nfwKoDiSYg8zOCREWAm5',
#   'duration_ms': 207853,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'type': 'audio_features',
#   'id': '0tgVpDi06FyKpA1z0VMD4v',
#   'uri': 'spotify:track:0tgVpDi06FyKpA1z0VMD4v',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tgVpDi06FyKpA1z0VMD4v',
#   'duration_ms': 263400,
#   'time_signature': 3},
#  {'danceability': 0.807,
#   'energy': 0.893,
#   'key': 11,
#   'loudness': -3.745,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 0.0451,
#   'instrumentalness': 2.79e-05,
#   'liveness': 0.366,
#   'valence': 0.537,
#   'tempo': 126.011,
#   'type': 'audio_features',
#   'id': '3rmo8F54jFF8OgYsqTxm5d',
#   'uri': 'spotify:track:3rmo8F54jFF8OgYsqTxm5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rmo8F54jFF8OgYsqTxm5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rmo8F54jFF8OgYsqTxm5d',
#   'duration_ms': 230747,
#   'time_signature': 4},
#  {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'type': 'audio_features',
#   'id': '7qiZfU4dY1lWllzX7mPBI3',
#   'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qiZfU4dY1lWllzX7mPBI3',
#   'duration_ms': 233713,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.852,
#   'key': 2,
#   'loudness': -1.248,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.0529,
#   'instrumentalness': 0,
#   'liveness': 0.161,
#   'valence': 0.501,
#   'tempo': 123.038,
#   'type': 'audio_features',
#   'id': '4zrKN5Sv8JS5mqnbVcsul7',
#   'uri': 'spotify:track:4zrKN5Sv8JS5mqnbVcsul7',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zrKN5Sv8JS5mqnbVcsul7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zrKN5Sv8JS5mqnbVcsul7',
#   'duration_ms': 209027,
#   'time_signature': 4},
#  {'danceability': 0.781,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -6.061,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.474,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.591,
#   'tempo': 78.998,
#   'type': 'audio_features',
#   'id': '34gCuhDGsG4bRPIf9bb02f',
#   'uri': 'spotify:track:34gCuhDGsG4bRPIf9bb02f',
#   'track_href': 'https://api.spotify.com/v1/tracks/34gCuhDGsG4bRPIf9bb02f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34gCuhDGsG4bRPIf9bb02f',
#   'duration_ms': 281560,
#   'time_signature': 4},
#  {'danceability': 0.756,
#   'energy': 0.697,
#   'key': 8,
#   'loudness': -6.377,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.182,
#   'instrumentalness': 0,
#   'liveness': 0.333,
#   'valence': 0.956,
#   'tempo': 94.996,
#   'type': 'audio_features',
#   'id': '0QBzMgT7NIeoCYy3sJCof1',
#   'uri': 'spotify:track:0QBzMgT7NIeoCYy3sJCof1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0QBzMgT7NIeoCYy3sJCof1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QBzMgT7NIeoCYy3sJCof1',
#   'duration_ms': 206071,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.834,
#   'key': 2,
#   'loudness': -4.868,
#   'mode': 1,
#   'speechiness': 0.0989,
#   'acousticness': 0.0232,
#   'instrumentalness': 1.14e-05,
#   'liveness': 0.14,
#   'valence': 0.471,
#   'tempo': 135.007,
#   'type': 'audio_features',
#   'id': '6PCUP3dWmTjcTtXY02oFdT',
#   'uri': 'spotify:track:6PCUP3dWmTjcTtXY02oFdT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PCUP3dWmTjcTtXY02oFdT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PCUP3dWmTjcTtXY02oFdT',
#   'duration_ms': 261154,
#   'time_signature': 4},
#  {'danceability': 0.751,
#   'energy': 0.618,
#   'key': 6,
#   'loudness': -6.643,
#   'mode': 0,
#   'speechiness': 0.324,
#   'acousticness': 0.596,
#   'instrumentalness': 0,
#   'liveness': 0.129,
#   'valence': 0.707,
#   'tempo': 93.728,
#   'type': 'audio_features',
#   'id': '5DFi6D7SrYHRIgZbY5MqqE',
#   'uri': 'spotify:track:5DFi6D7SrYHRIgZbY5MqqE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DFi6D7SrYHRIgZbY5MqqE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DFi6D7SrYHRIgZbY5MqqE',
#   'duration_ms': 204894,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.746,
#   'key': 8,
#   'loudness': -6.285,
#   'mode': 1,
#   'speechiness': 0.0711,
#   'acousticness': 0.0132,
#   'instrumentalness': 0,
#   'liveness': 0.067,
#   'valence': 0.182,
#   'tempo': 122.002,
#   'type': 'audio_features',
#   'id': '2tkmKj2zZd4EN9gkvJGcv7',
#   'uri': 'spotify:track:2tkmKj2zZd4EN9gkvJGcv7',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tkmKj2zZd4EN9gkvJGcv7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tkmKj2zZd4EN9gkvJGcv7',
#   'duration_ms': 249777,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.531,
#   'key': 7,
#   'loudness': -7.355,
#   'mode': 1,
#   'speechiness': 0.122,
#   'acousticness': 0.0703,
#   'instrumentalness': 0,
#   'liveness': 0.224,
#   'valence': 0.344,
#   'tempo': 71.994,
#   'type': 'audio_features',
#   'id': '2HbKqm4o0w5wEeEFXm2sD4',
#   'uri': 'spotify:track:2HbKqm4o0w5wEeEFXm2sD4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HbKqm4o0w5wEeEFXm2sD4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HbKqm4o0w5wEeEFXm2sD4',
#   'duration_ms': 386907,
#   'time_signature': 4},
#  {'danceability': 0.711,
#   'energy': 0.611,
#   'key': 1,
#   'loudness': -5.453,
#   'mode': 1,
#   'speechiness': 0.33,
#   'acousticness': 0.00588,
#   'instrumentalness': 0,
#   'liveness': 0.23,
#   'valence': 0.144,
#   'tempo': 134.093,
#   'type': 'audio_features',
#   'id': '3QFInJAm9eyaho5vBzxInN',
#   'uri': 'spotify:track:3QFInJAm9eyaho5vBzxInN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QFInJAm9eyaho5vBzxInN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QFInJAm9eyaho5vBzxInN',
#   'duration_ms': 252262,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.698,
#   'key': 1,
#   'loudness': -8.948,
#   'mode': 1,
#   'speechiness': 0.0943,
#   'acousticness': 0.0152,
#   'instrumentalness': 0,
#   'liveness': 0.442,
#   'valence': 0.0985,
#   'tempo': 133.954,
#   'type': 'audio_features',
#   'id': '4Pwjz3DfvfQWV0rO2V8jyh',
#   'uri': 'spotify:track:4Pwjz3DfvfQWV0rO2V8jyh',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Pwjz3DfvfQWV0rO2V8jyh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Pwjz3DfvfQWV0rO2V8jyh',
#   'duration_ms': 310720,
#   'time_signature': 4},
#  {'danceability': 0.79,
#   'energy': 0.67,
#   'key': 1,
#   'loudness': -5.527,
#   'mode': 1,
#   'speechiness': 0.105,
#   'acousticness': 0.377,
#   'instrumentalness': 2.32e-06,
#   'liveness': 0.119,
#   'valence': 0.408,
#   'tempo': 139.956,
#   'type': 'audio_features',
#   'id': '0fX4oNGBWO3dSGUZcVdVV2',
#   'uri': 'spotify:track:0fX4oNGBWO3dSGUZcVdVV2',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fX4oNGBWO3dSGUZcVdVV2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fX4oNGBWO3dSGUZcVdVV2',
#   'duration_ms': 195950,
#   'time_signature': 4},
#  {'danceability': 0.8,
#   'energy': 0.585,
#   'key': 10,
#   'loudness': -7.343,
#   'mode': 1,
#   'speechiness': 0.0924,
#   'acousticness': 0.264,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.779,
#   'tempo': 126.058,
#   'type': 'audio_features',
#   'id': '6PGoSes0D9eUDeeAafB2As',
#   'uri': 'spotify:track:6PGoSes0D9eUDeeAafB2As',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PGoSes0D9eUDeeAafB2As',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PGoSes0D9eUDeeAafB2As',
#   'duration_ms': 213400,
#   'time_signature': 4},
#  {'danceability': 0.711,
#   'energy': 0.611,
#   'key': 1,
#   'loudness': -5.453,
#   'mode': 1,
#   'speechiness': 0.329,
#   'acousticness': 0.00575,
#   'instrumentalness': 0,
#   'liveness': 0.231,
#   'valence': 0.144,
#   'tempo': 134.14,
#   'type': 'audio_features',
#   'id': '7Bpx2vsWfQFBACRz4h3IqH',
#   'uri': 'spotify:track:7Bpx2vsWfQFBACRz4h3IqH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Bpx2vsWfQFBACRz4h3IqH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Bpx2vsWfQFBACRz4h3IqH',
#   'duration_ms': 252070,
#   'time_signature': 4},
#  {'danceability': 0.908,
#   'energy': 0.621,
#   'key': 1,
#   'loudness': -6.638,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.000282,
#   'instrumentalness': 5.39e-05,
#   'liveness': 0.0958,
#   'valence': 0.421,
#   'tempo': 150.011,
#   'type': 'audio_features',
#   'id': '7KXjTSCq5nL1LoYtL7XAwS',
#   'uri': 'spotify:track:7KXjTSCq5nL1LoYtL7XAwS',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KXjTSCq5nL1LoYtL7XAwS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KXjTSCq5nL1LoYtL7XAwS',
#   'duration_ms': 177000,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.845,
#   'key': 8,
#   'loudness': -8.142,
#   'mode': 1,
#   'speechiness': 0.404,
#   'acousticness': 0.244,
#   'instrumentalness': 0,
#   'liveness': 0.143,
#   'valence': 0.331,
#   'tempo': 85.63,
#   'type': 'audio_features',
#   'id': '5Gt9bxniM1SxN61yRzRhXL',
#   'uri': 'spotify:track:5Gt9bxniM1SxN61yRzRhXL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Gt9bxniM1SxN61yRzRhXL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Gt9bxniM1SxN61yRzRhXL',
#   'duration_ms': 255378,
#   'time_signature': 3},
#  {'danceability': 0.698,
#   'energy': 0.633,
#   'key': 8,
#   'loudness': -4.946,
#   'mode': 1,
#   'speechiness': 0.0597,
#   'acousticness': 0.0605,
#   'instrumentalness': 0.000194,
#   'liveness': 0.0926,
#   'valence': 0.552,
#   'tempo': 96.924,
#   'type': 'audio_features',
#   'id': '3GCdLUSnKSMJhs4Tj6CV3s',
#   'uri': 'spotify:track:3GCdLUSnKSMJhs4Tj6CV3s',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GCdLUSnKSMJhs4Tj6CV3s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GCdLUSnKSMJhs4Tj6CV3s',
#   'duration_ms': 232187,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.447,
#   'key': 8,
#   'loudness': -5.892,
#   'mode': 1,
#   'speechiness': 0.277,
#   'acousticness': 0.00627,
#   'instrumentalness': 0.00022,
#   'liveness': 0.0899,
#   'valence': 0.189,
#   'tempo': 74.236,
#   'type': 'audio_features',
#   'id': '6REbwUNlppTfcnV4d4ZoZi',
#   'uri': 'spotify:track:6REbwUNlppTfcnV4d4ZoZi',
#   'track_href': 'https://api.spotify.com/v1/tracks/6REbwUNlppTfcnV4d4ZoZi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6REbwUNlppTfcnV4d4ZoZi',
#   'duration_ms': 247800,
#   'time_signature': 4},
#  {'danceability': 0.526,
#   'energy': 0.606,
#   'key': 5,
#   'loudness': -5.3,
#   'mode': 0,
#   'speechiness': 0.259,
#   'acousticness': 0.152,
#   'instrumentalness': 2.36e-06,
#   'liveness': 0.194,
#   'valence': 0.492,
#   'tempo': 116.622,
#   'type': 'audio_features',
#   'id': '0vjeOZ3Ft5jvAi9SBFJm1j',
#   'uri': 'spotify:track:0vjeOZ3Ft5jvAi9SBFJm1j',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vjeOZ3Ft5jvAi9SBFJm1j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vjeOZ3Ft5jvAi9SBFJm1j',
#   'duration_ms': 182667,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.486,
#   'key': 5,
#   'loudness': -6.497,
#   'mode': 0,
#   'speechiness': 0.0475,
#   'acousticness': 0.0538,
#   'instrumentalness': 0.497,
#   'liveness': 0.101,
#   'valence': 0.0894,
#   'tempo': 110.964,
#   'type': 'audio_features',
#   'id': '4lH6nENd1y81jp7Yt9lTBX',
#   'uri': 'spotify:track:4lH6nENd1y81jp7Yt9lTBX',
#   'track_href': 'https://api.spotify.com/v1/tracks/4lH6nENd1y81jp7Yt9lTBX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lH6nENd1y81jp7Yt9lTBX',
#   'duration_ms': 265996,
#   'time_signature': 4},
#  {'danceability': 0.883,
#   'energy': 0.657,
#   'key': 8,
#   'loudness': -5.748,
#   'mode': 1,
#   'speechiness': 0.305,
#   'acousticness': 0.0603,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.284,
#   'tempo': 124.992,
#   'type': 'audio_features',
#   'id': '1qMMYpVatbRITKCfq1gasi',
#   'uri': 'spotify:track:1qMMYpVatbRITKCfq1gasi',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qMMYpVatbRITKCfq1gasi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qMMYpVatbRITKCfq1gasi',
#   'duration_ms': 172933,
#   'time_signature': 4},
#  {'danceability': 0.463,
#   'energy': 0.642,
#   'key': 1,
#   'loudness': -4.474,
#   'mode': 1,
#   'speechiness': 0.34,
#   'acousticness': 0.314,
#   'instrumentalness': 0,
#   'liveness': 0.0686,
#   'valence': 0.339,
#   'tempo': 83.389,
#   'type': 'audio_features',
#   'id': '59nOXPmaKlBfGMDeOVGrIK',
#   'uri': 'spotify:track:59nOXPmaKlBfGMDeOVGrIK',
#   'track_href': 'https://api.spotify.com/v1/tracks/59nOXPmaKlBfGMDeOVGrIK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59nOXPmaKlBfGMDeOVGrIK',
#   'duration_ms': 189893,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.671,
#   'key': 7,
#   'loudness': -4.392,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.189,
#   'instrumentalness': 2.37e-05,
#   'liveness': 0.122,
#   'valence': 0.156,
#   'tempo': 88.048,
#   'type': 'audio_features',
#   'id': '2Hh3ETdQKrmSI3QS0hme7g',
#   'uri': 'spotify:track:2Hh3ETdQKrmSI3QS0hme7g',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Hh3ETdQKrmSI3QS0hme7g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Hh3ETdQKrmSI3QS0hme7g',
#   'duration_ms': 199920,
#   'time_signature': 4},
#  {'danceability': 0.709,
#   'energy': 0.357,
#   'key': 5,
#   'loudness': -9.289,
#   'mode': 1,
#   'speechiness': 0.214,
#   'acousticness': 0.478,
#   'instrumentalness': 0.000294,
#   'liveness': 0.112,
#   'valence': 0.544,
#   'tempo': 75.494,
#   'type': 'audio_features',
#   'id': '4XJRpBOG0bU3Nxnvam3FnC',
#   'uri': 'spotify:track:4XJRpBOG0bU3Nxnvam3FnC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4XJRpBOG0bU3Nxnvam3FnC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XJRpBOG0bU3Nxnvam3FnC',
#   'duration_ms': 129480,
#   'time_signature': 4},
#  {'danceability': 0.911,
#   'energy': 0.573,
#   'key': 2,
#   'loudness': -5.573,
#   'mode': 1,
#   'speechiness': 0.163,
#   'acousticness': 0.0112,
#   'instrumentalness': 5.83e-05,
#   'liveness': 0.131,
#   'valence': 0.145,
#   'tempo': 144.026,
#   'type': 'audio_features',
#   'id': '0AAVJIN4plafvmNKqRCltG',
#   'uri': 'spotify:track:0AAVJIN4plafvmNKqRCltG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0AAVJIN4plafvmNKqRCltG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0AAVJIN4plafvmNKqRCltG',
#   'duration_ms': 271840,
#   'time_signature': 4},
#  {'danceability': 0.773,
#   'energy': 0.707,
#   'key': 11,
#   'loudness': -5.71,
#   'mode': 1,
#   'speechiness': 0.0568,
#   'acousticness': 0.0103,
#   'instrumentalness': 1.04e-05,
#   'liveness': 0.296,
#   'valence': 0.113,
#   'tempo': 76.977,
#   'type': 'audio_features',
#   'id': '6wyhUr4Xw8z5uSy0AhoZfU',
#   'uri': 'spotify:track:6wyhUr4Xw8z5uSy0AhoZfU',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wyhUr4Xw8z5uSy0AhoZfU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wyhUr4Xw8z5uSy0AhoZfU',
#   'duration_ms': 236187,
#   'time_signature': 4},
#  {'danceability': 0.883,
#   'energy': 0.657,
#   'key': 8,
#   'loudness': -5.748,
#   'mode': 1,
#   'speechiness': 0.305,
#   'acousticness': 0.0603,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.284,
#   'tempo': 124.992,
#   'type': 'audio_features',
#   'id': '5qgFgsrrxOjyPmX5YCuK2E',
#   'uri': 'spotify:track:5qgFgsrrxOjyPmX5YCuK2E',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qgFgsrrxOjyPmX5YCuK2E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qgFgsrrxOjyPmX5YCuK2E',
#   'duration_ms': 172933,
#   'time_signature': 4},
#  {'danceability': 0.833,
#   'energy': 0.434,
#   'key': 2,
#   'loudness': -8.795,
#   'mode': 1,
#   'speechiness': 0.431,
#   'acousticness': 0.0102,
#   'instrumentalness': 0.0219,
#   'liveness': 0.165,
#   'valence': 0.281,
#   'tempo': 150.062,
#   'type': 'audio_features',
#   'id': '0VgkVdmE4gld66l8iyGjgx',
#   'uri': 'spotify:track:0VgkVdmE4gld66l8iyGjgx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VgkVdmE4gld66l8iyGjgx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VgkVdmE4gld66l8iyGjgx',
#   'duration_ms': 204600,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'type': 'audio_features',
#   'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BKLCZ1jbUBVqRi2FVlTVw',
#   'duration_ms': 244960,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.869,
#   'key': 11,
#   'loudness': -5.094,
#   'mode': 1,
#   'speechiness': 0.172,
#   'acousticness': 0.157,
#   'instrumentalness': 0.00508,
#   'liveness': 0.136,
#   'valence': 0.422,
#   'tempo': 159.803,
#   'type': 'audio_features',
#   'id': '1i1fxkWeaMmKEB4T7zqbzK',
#   'uri': 'spotify:track:1i1fxkWeaMmKEB4T7zqbzK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1i1fxkWeaMmKEB4T7zqbzK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1i1fxkWeaMmKEB4T7zqbzK',
#   'duration_ms': 208373,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.67,
#   'key': 9,
#   'loudness': -8.81,
#   'mode': 1,
#   'speechiness': 0.0496,
#   'acousticness': 0.009,
#   'instrumentalness': 0.000822,
#   'liveness': 0.0451,
#   'valence': 0.481,
#   'tempo': 151.553,
#   'type': 'audio_features',
#   'id': '5e9TFTbltYBg2xThimr0rU',
#   'uri': 'spotify:track:5e9TFTbltYBg2xThimr0rU',
#   'track_href': 'https://api.spotify.com/v1/tracks/5e9TFTbltYBg2xThimr0rU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5e9TFTbltYBg2xThimr0rU',
#   'duration_ms': 270213,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.635,
#   'key': 11,
#   'loudness': -6.769,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.0498,
#   'instrumentalness': 1.44e-05,
#   'liveness': 0.164,
#   'valence': 0.446,
#   'tempo': 103.019,
#   'type': 'audio_features',
#   'id': '6RUKPb4LETWmmr3iAEQktW',
#   'uri': 'spotify:track:6RUKPb4LETWmmr3iAEQktW',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RUKPb4LETWmmr3iAEQktW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RUKPb4LETWmmr3iAEQktW',
#   'duration_ms': 247160,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.787,
#   'key': 0,
#   'loudness': -6.178,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.0492,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.525,
#   'tempo': 134.981,
#   'type': 'audio_features',
#   'id': '09AvsbivV1FQBRAEBJh7UL',
#   'uri': 'spotify:track:09AvsbivV1FQBRAEBJh7UL',
#   'track_href': 'https://api.spotify.com/v1/tracks/09AvsbivV1FQBRAEBJh7UL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09AvsbivV1FQBRAEBJh7UL',
#   'duration_ms': 175163,
#   'time_signature': 4},
#  {'danceability': 0.713,
#   'energy': 0.802,
#   'key': 4,
#   'loudness': -7.055,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.0435,
#   'instrumentalness': 0.00377,
#   'liveness': 0.309,
#   'valence': 0.343,
#   'tempo': 100.001,
#   'type': 'audio_features',
#   'id': '3vv9phIu6Y1vX3jcqaGz5Z',
#   'uri': 'spotify:track:3vv9phIu6Y1vX3jcqaGz5Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/3vv9phIu6Y1vX3jcqaGz5Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3vv9phIu6Y1vX3jcqaGz5Z',
#   'duration_ms': 226739,
#   'time_signature': 4},
#  {'danceability': 0.665,
#   'energy': 0.628,
#   'key': 2,
#   'loudness': -6.297,
#   'mode': 1,
#   'speechiness': 0.026,
#   'acousticness': 0.00502,
#   'instrumentalness': 2.02e-05,
#   'liveness': 0.0947,
#   'valence': 0.551,
#   'tempo': 121.979,
#   'type': 'audio_features',
#   'id': '4edHoZerfvMGeLz3ohZit6',
#   'uri': 'spotify:track:4edHoZerfvMGeLz3ohZit6',
#   'track_href': 'https://api.spotify.com/v1/tracks/4edHoZerfvMGeLz3ohZit6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4edHoZerfvMGeLz3ohZit6',
#   'duration_ms': 202406,
#   'time_signature': 4},
#  {'danceability': 0.607,
#   'energy': 0.649,
#   'key': 11,
#   'loudness': -6.695,
#   'mode': 0,
#   'speechiness': 0.0362,
#   'acousticness': 0.0306,
#   'instrumentalness': 2.46e-05,
#   'liveness': 0.174,
#   'valence': 0.505,
#   'tempo': 102.996,
#   'type': 'audio_features',
#   'id': '1dNIEtp7AY3oDAKCGg2XkH',
#   'uri': 'spotify:track:1dNIEtp7AY3oDAKCGg2XkH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dNIEtp7AY3oDAKCGg2XkH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dNIEtp7AY3oDAKCGg2XkH',
#   'duration_ms': 247627,
#   'time_signature': 4},
#  {'danceability': 0.575,
#   'energy': 0.571,
#   'key': 1,
#   'loudness': -7.906,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.0558,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.449,
#   'tempo': 105.049,
#   'type': 'audio_features',
#   'id': '4NBTZtAt1F13VvlSKe6KTl',
#   'uri': 'spotify:track:4NBTZtAt1F13VvlSKe6KTl',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NBTZtAt1F13VvlSKe6KTl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NBTZtAt1F13VvlSKe6KTl',
#   'duration_ms': 197947,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.644,
#   'key': 2,
#   'loudness': -6.763,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.0243,
#   'instrumentalness': 0,
#   'liveness': 0.0888,
#   'valence': 0.251,
#   'tempo': 99.999,
#   'type': 'audio_features',
#   'id': '15vzANxN8G9wWfwAJLLMCg',
#   'uri': 'spotify:track:15vzANxN8G9wWfwAJLLMCg',
#   'track_href': 'https://api.spotify.com/v1/tracks/15vzANxN8G9wWfwAJLLMCg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15vzANxN8G9wWfwAJLLMCg',
#   'duration_ms': 221520,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.657,
#   'key': 7,
#   'loudness': -3.061,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.171,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.437,
#   'tempo': 107.01,
#   'type': 'audio_features',
#   'id': '09IStsImFySgyp0pIQdqAc',
#   'uri': 'spotify:track:09IStsImFySgyp0pIQdqAc',
#   'track_href': 'https://api.spotify.com/v1/tracks/09IStsImFySgyp0pIQdqAc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09IStsImFySgyp0pIQdqAc',
#   'duration_ms': 184732,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.781,
#   'key': 8,
#   'loudness': -3.48,
#   'mode': 1,
#   'speechiness': 0.072,
#   'acousticness': 0.0398,
#   'instrumentalness': 0,
#   'liveness': 0.0749,
#   'valence': 0.176,
#   'tempo': 128.0,
#   'type': 'audio_features',
#   'id': '60wwxj6Dd9NJlirf84wr2c',
#   'uri': 'spotify:track:60wwxj6Dd9NJlirf84wr2c',
#   'track_href': 'https://api.spotify.com/v1/tracks/60wwxj6Dd9NJlirf84wr2c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60wwxj6Dd9NJlirf84wr2c',
#   'duration_ms': 271427,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.738,
#   'key': 8,
#   'loudness': -3.109,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.109,
#   'instrumentalness': 0,
#   'liveness': 0.0947,
#   'valence': 0.461,
#   'tempo': 127.961,
#   'type': 'audio_features',
#   'id': '2QtJA4gbwe1AcanB2p21aP',
#   'uri': 'spotify:track:2QtJA4gbwe1AcanB2p21aP',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QtJA4gbwe1AcanB2p21aP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QtJA4gbwe1AcanB2p21aP',
#   'duration_ms': 217347,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.622,
#   'key': 5,
#   'loudness': -5.025,
#   'mode': 0,
#   'speechiness': 0.0622,
#   'acousticness': 0.253,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.544,
#   'tempo': 102.04,
#   'type': 'audio_features',
#   'id': '6uBhi9gBXWjanegOb2Phh0',
#   'uri': 'spotify:track:6uBhi9gBXWjanegOb2Phh0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6uBhi9gBXWjanegOb2Phh0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uBhi9gBXWjanegOb2Phh0',
#   'duration_ms': 210091,
#   'time_signature': 4},
#  {'danceability': 0.628,
#   'energy': 0.833,
#   'key': 11,
#   'loudness': -4.126,
#   'mode': 0,
#   'speechiness': 0.0282,
#   'acousticness': 0.0079,
#   'instrumentalness': 1.48e-05,
#   'liveness': 0.074,
#   'valence': 0.56,
#   'tempo': 128.003,
#   'type': 'audio_features',
#   'id': '2ISSQPb9LHHiV6ng2NXosL',
#   'uri': 'spotify:track:2ISSQPb9LHHiV6ng2NXosL',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ISSQPb9LHHiV6ng2NXosL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ISSQPb9LHHiV6ng2NXosL',
#   'duration_ms': 218293,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.702,
#   'key': 7,
#   'loudness': -5.324,
#   'mode': 0,
#   'speechiness': 0.0455,
#   'acousticness': 0.0064,
#   'instrumentalness': 4.35e-05,
#   'liveness': 0.204,
#   'valence': 0.284,
#   'tempo': 129.956,
#   'type': 'audio_features',
#   'id': '12KUFSHFgT0XCoiSlvdQi4',
#   'uri': 'spotify:track:12KUFSHFgT0XCoiSlvdQi4',
#   'track_href': 'https://api.spotify.com/v1/tracks/12KUFSHFgT0XCoiSlvdQi4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12KUFSHFgT0XCoiSlvdQi4',
#   'duration_ms': 214840,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.801,
#   'key': 0,
#   'loudness': -4.417,
#   'mode': 0,
#   'speechiness': 0.034,
#   'acousticness': 0.0137,
#   'instrumentalness': 0.00349,
#   'liveness': 0.127,
#   'valence': 0.407,
#   'tempo': 129.99,
#   'type': 'audio_features',
#   'id': '1dFkD1JfRMzwO6hwUsE8aS',
#   'uri': 'spotify:track:1dFkD1JfRMzwO6hwUsE8aS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dFkD1JfRMzwO6hwUsE8aS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dFkD1JfRMzwO6hwUsE8aS',
#   'duration_ms': 243413,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.61,
#   'key': 8,
#   'loudness': -4.713,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.351,
#   'instrumentalness': 0,
#   'liveness': 0.175,
#   'valence': 0.649,
#   'tempo': 128.15,
#   'type': 'audio_features',
#   'id': '1elhmWW7Bv0MOQj2gAsyoV',
#   'uri': 'spotify:track:1elhmWW7Bv0MOQj2gAsyoV',
#   'track_href': 'https://api.spotify.com/v1/tracks/1elhmWW7Bv0MOQj2gAsyoV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1elhmWW7Bv0MOQj2gAsyoV',
#   'duration_ms': 206000,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.846,
#   'key': 9,
#   'loudness': -2.876,
#   'mode': 0,
#   'speechiness': 0.0573,
#   'acousticness': 0.00537,
#   'instrumentalness': 6.62e-06,
#   'liveness': 0.145,
#   'valence': 0.366,
#   'tempo': 129.998,
#   'type': 'audio_features',
#   'id': '1JDIArrcepzWDTAWXdGYmP',
#   'uri': 'spotify:track:1JDIArrcepzWDTAWXdGYmP',
#   'track_href': 'https://api.spotify.com/v1/tracks/1JDIArrcepzWDTAWXdGYmP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1JDIArrcepzWDTAWXdGYmP',
#   'duration_ms': 240000,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.616,
#   'key': 4,
#   'loudness': -4.238,
#   'mode': 1,
#   'speechiness': 0.0645,
#   'acousticness': 0.378,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.508,
#   'tempo': 99.962,
#   'type': 'audio_features',
#   'id': '4Ce37cRWvM1vIGGynKcs22',
#   'uri': 'spotify:track:4Ce37cRWvM1vIGGynKcs22',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Ce37cRWvM1vIGGynKcs22',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ce37cRWvM1vIGGynKcs22',
#   'duration_ms': 181880,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.678,
#   'key': 8,
#   'loudness': -7.159,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.0151,
#   'instrumentalness': 5.71e-06,
#   'liveness': 0.101,
#   'valence': 0.404,
#   'tempo': 103.952,
#   'type': 'audio_features',
#   'id': '6oJ6le65B3SEqPwMRNXWjY',
#   'uri': 'spotify:track:6oJ6le65B3SEqPwMRNXWjY',
#   'track_href': 'https://api.spotify.com/v1/tracks/6oJ6le65B3SEqPwMRNXWjY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6oJ6le65B3SEqPwMRNXWjY',
#   'duration_ms': 228267,
#   'time_signature': 4},
#  {'danceability': 0.363,
#   'energy': 0.486,
#   'key': 4,
#   'loudness': -10.905,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'acousticness': 0.827,
#   'instrumentalness': 0.0445,
#   'liveness': 0.11,
#   'valence': 0.0923,
#   'tempo': 111.078,
#   'type': 'audio_features',
#   'id': '4X66U6SUjvZqiKYIpCWXnq',
#   'uri': 'spotify:track:4X66U6SUjvZqiKYIpCWXnq',
#   'track_href': 'https://api.spotify.com/v1/tracks/4X66U6SUjvZqiKYIpCWXnq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4X66U6SUjvZqiKYIpCWXnq',
#   'duration_ms': 487359,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.589,
#   'key': 2,
#   'loudness': -6.961,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.256,
#   'tempo': 122.037,
#   'type': 'audio_features',
#   'id': '3Ds1rReoW8ixyfCTe2R0zR',
#   'uri': 'spotify:track:3Ds1rReoW8ixyfCTe2R0zR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Ds1rReoW8ixyfCTe2R0zR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ds1rReoW8ixyfCTe2R0zR',
#   'duration_ms': 248973,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.533,
#   'key': 0,
#   'loudness': -6.596,
#   'mode': 1,
#   'speechiness': 0.0706,
#   'acousticness': 0.119,
#   'instrumentalness': 0,
#   'liveness': 0.0864,
#   'valence': 0.515,
#   'tempo': 99.968,
#   'type': 'audio_features',
#   'id': '12GEpg2XOPyqk03JZEZnJs',
#   'uri': 'spotify:track:12GEpg2XOPyqk03JZEZnJs',
#   'track_href': 'https://api.spotify.com/v1/tracks/12GEpg2XOPyqk03JZEZnJs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12GEpg2XOPyqk03JZEZnJs',
#   'duration_ms': 220781,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.489,
#   'key': 5,
#   'loudness': -7.938,
#   'mode': 1,
#   'speechiness': 0.0788,
#   'acousticness': 0.13,
#   'instrumentalness': 0.00022,
#   'liveness': 0.0815,
#   'valence': 0.645,
#   'tempo': 114.008,
#   'type': 'audio_features',
#   'id': '7vHshinTU8161w69EPbabY',
#   'uri': 'spotify:track:7vHshinTU8161w69EPbabY',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vHshinTU8161w69EPbabY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vHshinTU8161w69EPbabY',
#   'duration_ms': 351579,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.585,
#   'key': 2,
#   'loudness': -5.994,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.225,
#   'instrumentalness': 0,
#   'liveness': 0.0927,
#   'valence': 0.188,
#   'tempo': 106.015,
#   'type': 'audio_features',
#   'id': '21H0pUV2uPIPcFnFhgTBjo',
#   'uri': 'spotify:track:21H0pUV2uPIPcFnFhgTBjo',
#   'track_href': 'https://api.spotify.com/v1/tracks/21H0pUV2uPIPcFnFhgTBjo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21H0pUV2uPIPcFnFhgTBjo',
#   'duration_ms': 216873,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.642,
#   'key': 1,
#   'loudness': -5.473,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.289,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.218,
#   'tempo': 117.94,
#   'type': 'audio_features',
#   'id': '1O73ZKgl0THUImkHW6dfAL',
#   'uri': 'spotify:track:1O73ZKgl0THUImkHW6dfAL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1O73ZKgl0THUImkHW6dfAL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1O73ZKgl0THUImkHW6dfAL',
#   'duration_ms': 202158,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.391,
#   'key': 1,
#   'loudness': -6.116,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.87,
#   'instrumentalness': 0,
#   'liveness': 0.133,
#   'valence': 0.3,
#   'tempo': 105.533,
#   'type': 'audio_features',
#   'id': '0ryULsOBEF00i4XwnF3brE',
#   'uri': 'spotify:track:0ryULsOBEF00i4XwnF3brE',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ryULsOBEF00i4XwnF3brE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ryULsOBEF00i4XwnF3brE',
#   'duration_ms': 182500,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.635,
#   'key': 8,
#   'loudness': -7.565,
#   'mode': 0,
#   'speechiness': 0.226,
#   'acousticness': 0.271,
#   'instrumentalness': 0,
#   'liveness': 0.319,
#   'valence': 0.475,
#   'tempo': 100.034,
#   'type': 'audio_features',
#   'id': '5masKPHeAOVNgxdLebIcK7',
#   'uri': 'spotify:track:5masKPHeAOVNgxdLebIcK7',
#   'track_href': 'https://api.spotify.com/v1/tracks/5masKPHeAOVNgxdLebIcK7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5masKPHeAOVNgxdLebIcK7',
#   'duration_ms': 223187,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.586,
#   'key': 1,
#   'loudness': -6.883,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.344,
#   'instrumentalness': 0,
#   'liveness': 0.0755,
#   'valence': 0.507,
#   'tempo': 147.988,
#   'type': 'audio_features',
#   'id': '1sgDyuLooyvEML4oHspNza',
#   'uri': 'spotify:track:1sgDyuLooyvEML4oHspNza',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sgDyuLooyvEML4oHspNza',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sgDyuLooyvEML4oHspNza',
#   'duration_ms': 199549,
#   'time_signature': 4},
#  {'danceability': 0.775,
#   'energy': 0.68,
#   'key': 0,
#   'loudness': -5.508,
#   'mode': 0,
#   'speechiness': 0.0629,
#   'acousticness': 0.00906,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.656,
#   'tempo': 114.025,
#   'type': 'audio_features',
#   'id': '7oGZAicScQt96OAW4AruYy',
#   'uri': 'spotify:track:7oGZAicScQt96OAW4AruYy',
#   'track_href': 'https://api.spotify.com/v1/tracks/7oGZAicScQt96OAW4AruYy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7oGZAicScQt96OAW4AruYy',
#   'duration_ms': 207719,
#   'time_signature': 4},
#  {'danceability': 0.615,
#   'energy': 0.711,
#   'key': 11,
#   'loudness': -5.507,
#   'mode': 1,
#   'speechiness': 0.0779,
#   'acousticness': 0.0444,
#   'instrumentalness': 0,
#   'liveness': 0.145,
#   'valence': 0.711,
#   'tempo': 144.036,
#   'type': 'audio_features',
#   'id': '67T6l4q3zVjC5nZZPXByU8',
#   'uri': 'spotify:track:67T6l4q3zVjC5nZZPXByU8',
#   'track_href': 'https://api.spotify.com/v1/tracks/67T6l4q3zVjC5nZZPXByU8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67T6l4q3zVjC5nZZPXByU8',
#   'duration_ms': 221253,
#   'time_signature': 4},
#  {'danceability': 0.76,
#   'energy': 0.652,
#   'key': 6,
#   'loudness': -7.321,
#   'mode': 1,
#   'speechiness': 0.232,
#   'acousticness': 0.0348,
#   'instrumentalness': 0,
#   'liveness': 0.307,
#   'valence': 0.759,
#   'tempo': 100.315,
#   'type': 'audio_features',
#   'id': '6g6A7qNhTfUgOSH7ROOxTD',
#   'uri': 'spotify:track:6g6A7qNhTfUgOSH7ROOxTD',
#   'track_href': 'https://api.spotify.com/v1/tracks/6g6A7qNhTfUgOSH7ROOxTD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6g6A7qNhTfUgOSH7ROOxTD',
#   'duration_ms': 177685,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.691,
#   'key': 0,
#   'loudness': -4.862,
#   'mode': 1,
#   'speechiness': 0.258,
#   'acousticness': 0.555,
#   'instrumentalness': 0,
#   'liveness': 0.097,
#   'valence': 0.638,
#   'tempo': 82.142,
#   'type': 'audio_features',
#   'id': '5KONnBIQ9LqCxyeSPin26k',
#   'uri': 'spotify:track:5KONnBIQ9LqCxyeSPin26k',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KONnBIQ9LqCxyeSPin26k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KONnBIQ9LqCxyeSPin26k',
#   'duration_ms': 217419,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.792,
#   'key': 10,
#   'loudness': -4.021,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.051,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.507,
#   'tempo': 122.062,
#   'type': 'audio_features',
#   'id': '3eJH2nAjvNXdmPfBkALiPZ',
#   'uri': 'spotify:track:3eJH2nAjvNXdmPfBkALiPZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3eJH2nAjvNXdmPfBkALiPZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3eJH2nAjvNXdmPfBkALiPZ',
#   'duration_ms': 139672,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.83,
#   'key': 9,
#   'loudness': -4.02,
#   'mode': 1,
#   'speechiness': 0.146,
#   'acousticness': 0.128,
#   'instrumentalness': 0,
#   'liveness': 0.129,
#   'valence': 0.578,
#   'tempo': 89.338,
#   'type': 'audio_features',
#   'id': '6BaxqcoEM9r3LXisTyJjST',
#   'uri': 'spotify:track:6BaxqcoEM9r3LXisTyJjST',
#   'track_href': 'https://api.spotify.com/v1/tracks/6BaxqcoEM9r3LXisTyJjST',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BaxqcoEM9r3LXisTyJjST',
#   'duration_ms': 215747,
#   'time_signature': 4},
#  {'danceability': 0.697,
#   'energy': 0.621,
#   'key': 9,
#   'loudness': -6.886,
#   'mode': 0,
#   'speechiness': 0.25,
#   'acousticness': 0.0802,
#   'instrumentalness': 0,
#   'liveness': 0.162,
#   'valence': 0.721,
#   'tempo': 81.946,
#   'type': 'audio_features',
#   'id': '2sLwPnIP3CUVmIuHranJZU',
#   'uri': 'spotify:track:2sLwPnIP3CUVmIuHranJZU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2sLwPnIP3CUVmIuHranJZU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2sLwPnIP3CUVmIuHranJZU',
#   'duration_ms': 193296,
#   'time_signature': 4},
#  {'danceability': 0.767,
#   'energy': 0.481,
#   'key': 0,
#   'loudness': -8.52,
# ...
#   'energy': 0.672,
#   'key': 10,
#   'loudness': -7.666,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.75,
#   'instrumentalness': 0.0837,
#   'liveness': 0.367,
#   'valence': 0.79,
#   'tempo': 126.509,
#   'type': 'audio_features',
#   'id': '1sQ5WUWw3JrsSEhdiQlfRt',
#   'uri': 'spotify:track:1sQ5WUWw3JrsSEhdiQlfRt',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sQ5WUWw3JrsSEhdiQlfRt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sQ5WUWw3JrsSEhdiQlfRt',
#   'duration_ms': 162320,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.846,
#   'key': 9,
#   'loudness': -5.602,
#   'mode': 1,
#   'speechiness': 0.0462,
#   'acousticness': 0.274,
#   'instrumentalness': 0.00306,
#   'liveness': 0.111,
#   'valence': 0.869,
#   'tempo': 109.988,
#   'type': 'audio_features',
#   'id': '6IoAmYqsvyKIFG8tfT2wTh',
#   'uri': 'spotify:track:6IoAmYqsvyKIFG8tfT2wTh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6IoAmYqsvyKIFG8tfT2wTh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6IoAmYqsvyKIFG8tfT2wTh',
#   'duration_ms': 257413,
#   'time_signature': 4},
#  {'danceability': 0.486,
#   'energy': 0.369,
#   'key': 10,
#   'loudness': -10.334,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.811,
#   'instrumentalness': 0,
#   'liveness': 0.129,
#   'valence': 0.719,
#   'tempo': 98.951,
#   'type': 'audio_features',
#   'id': '4Ot4EDIVVitLhtzclrEO45',
#   'uri': 'spotify:track:4Ot4EDIVVitLhtzclrEO45',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Ot4EDIVVitLhtzclrEO45',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ot4EDIVVitLhtzclrEO45',
#   'duration_ms': 153880,
#   'time_signature': 4},
#  {'danceability': 0.318,
#   'energy': 0.657,
#   'key': 2,
#   'loudness': -11.829,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.101,
#   'instrumentalness': 3.01e-06,
#   'liveness': 0.144,
#   'valence': 0.753,
#   'tempo': 177.477,
#   'type': 'audio_features',
#   'id': '5orygsZ5Ga0jEOvftsXqw2',
#   'uri': 'spotify:track:5orygsZ5Ga0jEOvftsXqw2',
#   'track_href': 'https://api.spotify.com/v1/tracks/5orygsZ5Ga0jEOvftsXqw2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5orygsZ5Ga0jEOvftsXqw2',
#   'duration_ms': 190373,
#   'time_signature': 4},
#  {'danceability': 0.479,
#   'energy': 0.729,
#   'key': 9,
#   'loudness': -10.044,
#   'mode': 0,
#   'speechiness': 0.132,
#   'acousticness': 0.00251,
#   'instrumentalness': 0,
#   'liveness': 0.293,
#   'valence': 0.233,
#   'tempo': 133.882,
#   'type': 'audio_features',
#   'id': '0DSy1QzTO8k8lj88GkhZky',
#   'uri': 'spotify:track:0DSy1QzTO8k8lj88GkhZky',
#   'track_href': 'https://api.spotify.com/v1/tracks/0DSy1QzTO8k8lj88GkhZky',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DSy1QzTO8k8lj88GkhZky',
#   'duration_ms': 140399,
#   'time_signature': 4},
#  {'danceability': 0.466,
#   'energy': 0.476,
#   'key': 11,
#   'loudness': -9.289,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.749,
#   'instrumentalness': 0,
#   'liveness': 0.22,
#   'valence': 0.856,
#   'tempo': 133.731,
#   'type': 'audio_features',
#   'id': '0hbC2CAJidLslKqJ39Lxh4',
#   'uri': 'spotify:track:0hbC2CAJidLslKqJ39Lxh4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0hbC2CAJidLslKqJ39Lxh4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0hbC2CAJidLslKqJ39Lxh4',
#   'duration_ms': 145467,
#   'time_signature': 4},
#  {'danceability': 0.437,
#   'energy': 0.583,
#   'key': 10,
#   'loudness': -8.9,
#   'mode': 1,
#   'speechiness': 0.032,
#   'acousticness': 0.159,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.832,
#   'tempo': 176.212,
#   'type': 'audio_features',
#   'id': '3ULUtkjRdO2bhPGorDh0mC',
#   'uri': 'spotify:track:3ULUtkjRdO2bhPGorDh0mC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ULUtkjRdO2bhPGorDh0mC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ULUtkjRdO2bhPGorDh0mC',
#   'duration_ms': 164653,
#   'time_signature': 4},
#  {'danceability': 0.567,
#   'energy': 0.672,
#   'key': 10,
#   'loudness': -7.666,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.75,
#   'instrumentalness': 0.0837,
#   'liveness': 0.367,
#   'valence': 0.79,
#   'tempo': 126.509,
#   'type': 'audio_features',
#   'id': '6Ln9F9lZNMgV5Ht87z9Bd0',
#   'uri': 'spotify:track:6Ln9F9lZNMgV5Ht87z9Bd0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Ln9F9lZNMgV5Ht87z9Bd0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Ln9F9lZNMgV5Ht87z9Bd0',
#   'duration_ms': 162320,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.486,
#   'key': 2,
#   'loudness': -8.839,
#   'mode': 1,
#   'speechiness': 0.0297,
#   'acousticness': 0.0551,
#   'instrumentalness': 0,
#   'liveness': 0.0888,
#   'valence': 0.656,
#   'tempo': 94.949,
#   'type': 'audio_features',
#   'id': '6TpEvRDyKjLYAreDsdbiU9',
#   'uri': 'spotify:track:6TpEvRDyKjLYAreDsdbiU9',
#   'track_href': 'https://api.spotify.com/v1/tracks/6TpEvRDyKjLYAreDsdbiU9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6TpEvRDyKjLYAreDsdbiU9',
#   'duration_ms': 211173,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.91,
#   'key': 7,
#   'loudness': -2.769,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.04,
#   'instrumentalness': 0,
#   'liveness': 0.319,
#   'valence': 0.588,
#   'tempo': 176.084,
#   'type': 'audio_features',
#   'id': '2Wkm4JBcIV2uSuu4qlbqFN',
#   'uri': 'spotify:track:2Wkm4JBcIV2uSuu4qlbqFN',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Wkm4JBcIV2uSuu4qlbqFN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wkm4JBcIV2uSuu4qlbqFN',
#   'duration_ms': 249215,
#   'time_signature': 4},
#  {'danceability': 0.661,
#   'energy': 0.836,
#   'key': 1,
#   'loudness': -4.079,
#   'mode': 0,
#   'speechiness': 0.0297,
#   'acousticness': 0.00615,
#   'instrumentalness': 0,
#   'liveness': 0.032,
#   'valence': 0.799,
#   'tempo': 137.507,
#   'type': 'audio_features',
#   'id': '08KTQSs3ickNki7FFTb6fY',
#   'uri': 'spotify:track:08KTQSs3ickNki7FFTb6fY',
#   'track_href': 'https://api.spotify.com/v1/tracks/08KTQSs3ickNki7FFTb6fY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08KTQSs3ickNki7FFTb6fY',
#   'duration_ms': 187385,
#   'time_signature': 4},
#  {'danceability': 0.364,
#   'energy': 0.607,
#   'key': 2,
#   'loudness': -9.791,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.451,
#   'instrumentalness': 0,
#   'liveness': 0.251,
#   'valence': 0.598,
#   'tempo': 79.987,
#   'type': 'audio_features',
#   'id': '1DndHckdH9m5rp6gYP086b',
#   'uri': 'spotify:track:1DndHckdH9m5rp6gYP086b',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DndHckdH9m5rp6gYP086b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DndHckdH9m5rp6gYP086b',
#   'duration_ms': 171600,
#   'time_signature': 4},
#  {'danceability': 0.447,
#   'energy': 0.0136,
#   'key': 2,
#   'loudness': -26.598,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.985,
#   'instrumentalness': 0.931,
#   'liveness': 0.108,
#   'valence': 0.14,
#   'tempo': 67.659,
#   'type': 'audio_features',
#   'id': '0OyfmSpjOUz6k0swecwQEw',
#   'uri': 'spotify:track:0OyfmSpjOUz6k0swecwQEw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0OyfmSpjOUz6k0swecwQEw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0OyfmSpjOUz6k0swecwQEw',
#   'duration_ms': 148662,
#   'time_signature': 4},
#  {'danceability': 0.512,
#   'energy': 0.415,
#   'key': 7,
#   'loudness': -7.642,
#   'mode': 1,
#   'speechiness': 0.0608,
#   'acousticness': 0.872,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.714,
#   'tempo': 147.2,
#   'type': 'audio_features',
#   'id': '05XkMS2YVNfPNXepMScPRJ',
#   'uri': 'spotify:track:05XkMS2YVNfPNXepMScPRJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/05XkMS2YVNfPNXepMScPRJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05XkMS2YVNfPNXepMScPRJ',
#   'duration_ms': 188360,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.546,
#   'key': 7,
#   'loudness': -10.213,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.301,
#   'instrumentalness': 0,
#   'liveness': 0.0936,
#   'valence': 0.855,
#   'tempo': 114.04,
#   'type': 'audio_features',
#   'id': '3v8d3ku3kiTZVPxEt7a2dE',
#   'uri': 'spotify:track:3v8d3ku3kiTZVPxEt7a2dE',
#   'track_href': 'https://api.spotify.com/v1/tracks/3v8d3ku3kiTZVPxEt7a2dE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v8d3ku3kiTZVPxEt7a2dE',
#   'duration_ms': 168640,
#   'time_signature': 4},
#  {'danceability': 0.331,
#   'energy': 0.61,
#   'key': 9,
#   'loudness': -8.138,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.00269,
#   'instrumentalness': 0.0548,
#   'liveness': 0.14,
#   'valence': 0.55,
#   'tempo': 132.746,
#   'type': 'audio_features',
#   'id': '7wYU1avLwl1Gtkib8OTrZp',
#   'uri': 'spotify:track:7wYU1avLwl1Gtkib8OTrZp',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wYU1avLwl1Gtkib8OTrZp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wYU1avLwl1Gtkib8OTrZp',
#   'duration_ms': 209040,
#   'time_signature': 4},
#  {'danceability': 0.384,
#   'energy': 0.438,
#   'key': 0,
#   'loudness': -9.149,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.753,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.287,
#   'tempo': 87.903,
#   'type': 'audio_features',
#   'id': '5EQzuYfTZt7B2LqlvTF49l',
#   'uri': 'spotify:track:5EQzuYfTZt7B2LqlvTF49l',
#   'track_href': 'https://api.spotify.com/v1/tracks/5EQzuYfTZt7B2LqlvTF49l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EQzuYfTZt7B2LqlvTF49l',
#   'duration_ms': 456867,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.33,
#   'key': 5,
#   'loudness': -9.027,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.719,
#   'instrumentalness': 8.6e-05,
#   'liveness': 0.136,
#   'valence': 0.524,
#   'tempo': 98.605,
#   'type': 'audio_features',
#   'id': '3xsOtNxtBW0oTI1OWKAzTm',
#   'uri': 'spotify:track:3xsOtNxtBW0oTI1OWKAzTm',
#   'track_href': 'https://api.spotify.com/v1/tracks/3xsOtNxtBW0oTI1OWKAzTm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xsOtNxtBW0oTI1OWKAzTm',
#   'duration_ms': 178333,
#   'time_signature': 4},
#  {'danceability': 0.358,
#   'energy': 0.525,
#   'key': 0,
#   'loudness': -10.077,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.473,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.891,
#   'tempo': 71.257,
#   'type': 'audio_features',
#   'id': '5UvR3VWxfVVKMgGrD3XZVj',
#   'uri': 'spotify:track:5UvR3VWxfVVKMgGrD3XZVj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UvR3VWxfVVKMgGrD3XZVj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UvR3VWxfVVKMgGrD3XZVj',
#   'duration_ms': 138667,
#   'time_signature': 4},
#  {'danceability': 0.249,
#   'energy': 0.66,
#   'key': 0,
#   'loudness': -6.905,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'acousticness': 0.504,
#   'instrumentalness': 0.0026,
#   'liveness': 0.0891,
#   'valence': 0.435,
#   'tempo': 149.813,
#   'type': 'audio_features',
#   'id': '1cmjxqobVTrgAiJ0btAleN',
#   'uri': 'spotify:track:1cmjxqobVTrgAiJ0btAleN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1cmjxqobVTrgAiJ0btAleN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cmjxqobVTrgAiJ0btAleN',
#   'duration_ms': 248947,
#   'time_signature': 4},
#  {'danceability': 0.249,
#   'energy': 0.66,
#   'key': 0,
#   'loudness': -6.905,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'acousticness': 0.504,
#   'instrumentalness': 0.0026,
#   'liveness': 0.0891,
#   'valence': 0.435,
#   'tempo': 149.813,
#   'type': 'audio_features',
#   'id': '78ZqE2tjAxbqEGGlvGnQfT',
#   'uri': 'spotify:track:78ZqE2tjAxbqEGGlvGnQfT',
#   'track_href': 'https://api.spotify.com/v1/tracks/78ZqE2tjAxbqEGGlvGnQfT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78ZqE2tjAxbqEGGlvGnQfT',
#   'duration_ms': 248947,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.571,
#   'key': 7,
#   'loudness': -17.235,
#   'mode': 0,
#   'speechiness': 0.25,
#   'acousticness': 0.145,
#   'instrumentalness': 0.0445,
#   'liveness': 0.513,
#   'valence': 0.32,
#   'tempo': 134.93,
#   'type': 'audio_features',
#   'id': '1dcu8JF2CVyZsR9ff1CnG9',
#   'uri': 'spotify:track:1dcu8JF2CVyZsR9ff1CnG9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dcu8JF2CVyZsR9ff1CnG9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dcu8JF2CVyZsR9ff1CnG9',
#   'duration_ms': 307333,
#   'time_signature': 4},
#  {'danceability': 0.438,
#   'energy': 0.837,
#   'key': 5,
#   'loudness': -6.416,
#   'mode': 0,
#   'speechiness': 0.0873,
#   'acousticness': 0.248,
#   'instrumentalness': 9.73e-05,
#   'liveness': 0.135,
#   'valence': 0.616,
#   'tempo': 125.092,
#   'type': 'audio_features',
#   'id': '2Wr1PqAw6bzMYhngpb3f96',
#   'uri': 'spotify:track:2Wr1PqAw6bzMYhngpb3f96',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Wr1PqAw6bzMYhngpb3f96',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wr1PqAw6bzMYhngpb3f96',
#   'duration_ms': 158147,
#   'time_signature': 4},
#  {'danceability': 0.361,
#   'energy': 0.658,
#   'key': 10,
#   'loudness': -7.893,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.0973,
#   'instrumentalness': 0.047,
#   'liveness': 0.0636,
#   'valence': 0.375,
#   'tempo': 142.242,
#   'type': 'audio_features',
#   'id': '1nxxYKsraVrPnNRzISliwM',
#   'uri': 'spotify:track:1nxxYKsraVrPnNRzISliwM',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nxxYKsraVrPnNRzISliwM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nxxYKsraVrPnNRzISliwM',
#   'duration_ms': 237400,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -7.219,
#   'mode': 1,
#   'speechiness': 0.0511,
#   'acousticness': 0.611,
#   'instrumentalness': 1.51e-06,
#   'liveness': 0.106,
#   'valence': 0.924,
#   'tempo': 89.413,
#   'type': 'audio_features',
#   'id': '7L46et7T4ogH7wTLnhS5X6',
#   'uri': 'spotify:track:7L46et7T4ogH7wTLnhS5X6',
#   'track_href': 'https://api.spotify.com/v1/tracks/7L46et7T4ogH7wTLnhS5X6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L46et7T4ogH7wTLnhS5X6',
#   'duration_ms': 206213,
#   'time_signature': 4},
#  {'danceability': 0.286,
#   'energy': 0.444,
#   'key': 0,
#   'loudness': -13.237,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.00526,
#   'instrumentalness': 0.022,
#   'liveness': 0.0939,
#   'valence': 0.16,
#   'tempo': 148.192,
#   'type': 'audio_features',
#   'id': '6BM20UqcuURtChTqsohkWR',
#   'uri': 'spotify:track:6BM20UqcuURtChTqsohkWR',
#   'track_href': 'https://api.spotify.com/v1/tracks/6BM20UqcuURtChTqsohkWR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BM20UqcuURtChTqsohkWR',
#   'duration_ms': 354783,
#   'time_signature': 4},
#  {'danceability': 0.345,
#   'energy': 0.655,
#   'key': 0,
#   'loudness': -7.716,
#   'mode': 0,
#   'speechiness': 0.0352,
#   'acousticness': 0.289,
#   'instrumentalness': 0.793,
#   'liveness': 0.0641,
#   'valence': 0.37,
#   'tempo': 137.743,
#   'type': 'audio_features',
#   'id': '3oU71W9KUFDllbYWjKaqwL',
#   'uri': 'spotify:track:3oU71W9KUFDllbYWjKaqwL',
#   'track_href': 'https://api.spotify.com/v1/tracks/3oU71W9KUFDllbYWjKaqwL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3oU71W9KUFDllbYWjKaqwL',
#   'duration_ms': 305573,
#   'time_signature': 4},
#  {'danceability': 0.286,
#   'energy': 0.444,
#   'key': 0,
#   'loudness': -13.237,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.00526,
#   'instrumentalness': 0.022,
#   'liveness': 0.0939,
#   'valence': 0.16,
#   'tempo': 148.192,
#   'type': 'audio_features',
#   'id': '3tzs4V1puuqjRKTHuFiyd0',
#   'uri': 'spotify:track:3tzs4V1puuqjRKTHuFiyd0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tzs4V1puuqjRKTHuFiyd0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tzs4V1puuqjRKTHuFiyd0',
#   'duration_ms': 354783,
#   'time_signature': 4},
#  {'danceability': 0.263,
#   'energy': 0.754,
#   'key': 10,
#   'loudness': -7.278,
#   'mode': 1,
#   'speechiness': 0.0865,
#   'acousticness': 0.175,
#   'instrumentalness': 6.21e-05,
#   'liveness': 0.112,
#   'valence': 0.574,
#   'tempo': 170.105,
#   'type': 'audio_features',
#   'id': '7sslK5uo7qDHTqqfQt2w7i',
#   'uri': 'spotify:track:7sslK5uo7qDHTqqfQt2w7i',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sslK5uo7qDHTqqfQt2w7i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sslK5uo7qDHTqqfQt2w7i',
#   'duration_ms': 308707,
#   'time_signature': 4},
#  ...]
